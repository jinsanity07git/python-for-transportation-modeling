# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import larch
from larch.data_warehouse import example_file
from larch import P,X

# %% [markdown]
# # 嵌套Logit模型

# %% [markdown]
# ## 理论回顾
#
# - 多项Logit（MNL）模型的无关选择属性（IIA）使得该模型不适用于在某些选择中存在观察和未观察属性的情况下的应用。
#
# - 在备选方案之间共享未观察属性违反了MNL模型发展中使用的独立同分布（IID）假设，并导致这些备选方案之间的竞争增加。
#
# - 考虑城市出行方式选择，其中有四个备选方案，其中两个是公共交通备选方案（例如，巴士和轻轨），它们在许多变量（包括公共票价结构、管理和人员、运营政策、缺乏隐私等）方面相似。
#
# - 这些属性中的一些，如票价和运营时间，可以观察到，而其他一些则可能无法观察到。这些关系可以用以下“树”结构表示：

# %%
from larch.model.tree import NestingTree
t = NestingTree()
# t.add_node(0, name='mode', root=True)
da = t.new_node(name='独自驾驶')
sr = t.new_node(name='拼车')
bus = t.new_node(name='巴士')
ltr = t.new_node(name='轻轨')
tr = t.new_node(name='公交', children=[3,4])
# t._root_id = "modes"
t
# Out:
# <div xmlns="http://www.w3.org/2000/svg"><svg width="590pt" height="204pt" viewBox="0.00 0.00 590.00 204.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 200)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-200 586,-200 586,4 -4,4"></polygon>
# <g id="clust1" class="cluster">
# <title>cluster_elemental</title>
# <path fill="lightgrey" stroke="white" d="M20,-8C20,-8 562,-8 562,-8 568,-8 574,-14 574,-20 574,-20 574,-48 574,-48 574,-54 568,-60 562,-60 562,-60 20,-60 20,-60 14,-60 8,-54 8,-48 8,-48 8,-20 8,-20 8,-14 14,-8 20,-8"></path>
# </g>
#
# <g id="node1" class="node">
# <title>0</title>
# <polygon fill="none" stroke="black" points="223,-172.44 250,-160 277,-172.44 276.97,-192.56 223.03,-192.56 223,-172.44"></polygon>
# <text text-anchor="middle" x="250" y="-172.57" font-family="Times,serif" font-size="14.00">0</text>
# </g>
#
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="white" stroke="black" cx="88" cy="-34" rx="72.02" ry="18"></ellipse>
# <text text-anchor="start" x="41.88" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(1) </text>
# <text text-anchor="start" x="59.88" y="-29.57" font-family="Times,serif" font-size="14.00">Drive Alone</text>
# </g>
#
# <g id="edge1" class="edge">
# <title>0-&gt;1</title>
# <path fill="none" stroke="black" d="M237.02,-165.62C210.67,-142.53 150.45,-89.74 115.16,-58.81"></path>
# <polygon fill="black" stroke="black" points="118.01,-55.77 108.18,-51.81 113.39,-61.04 118.01,-55.77"></polygon>
# </g>
#
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="white" stroke="black" cx="250" cy="-34" rx="72.02" ry="18"></ellipse>
# <text text-anchor="start" x="203.88" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(2) </text>
# <text text-anchor="start" x="221.88" y="-29.57" font-family="Times,serif" font-size="14.00">Shared Ride</text>
# </g>
#
# <g id="edge2" class="edge">
# <title>0-&gt;2</title>
# <path fill="none" stroke="black" d="M250,-159.59C250,-135.5 250,-91.75 250,-63.03"></path>
# <polygon fill="black" stroke="black" points="253.5,-63.11 250,-53.11 246.5,-63.11 253.5,-63.11"></polygon>
# </g>
#
# <g id="node6" class="node">
# <title>5</title>
# <path fill="none" stroke="black" d="M436.62,-124C436.62,-124 379.38,-124 379.38,-124 373.38,-124 367.38,-118 367.38,-112 367.38,-112 367.38,-100 367.38,-100 367.38,-94 373.38,-88 379.38,-88 379.38,-88 436.62,-88 436.62,-88 442.62,-88 448.62,-94 448.62,-100 448.62,-100 448.62,-112 448.62,-112 448.62,-118 442.62,-124 436.62,-124"></path>
# <text text-anchor="start" x="375.38" y="-101.58" font-family="Times,serif" font-size="9.00" fill="#999999">(5) </text>
# <text text-anchor="start" x="393.38" y="-101.58" font-family="Times,serif" font-size="14.00">Transit</text>
# </g>
#
# <g id="edge3" class="edge">
# <title>0-&gt;5</title>
# <path fill="none" stroke="black" d="M269.37,-168.42C291.51,-158.61 328.58,-142.19 358.82,-128.79"></path>
# <polygon fill="black" stroke="black" points="360.05,-131.63 367.78,-124.38 357.22,-125.23 360.05,-131.63"></polygon>
# </g>
#
# <g id="node4" class="node">
# <title>3</title>
# <ellipse fill="white" stroke="black" cx="530" cy="-34" rx="36.09" ry="18"></ellipse>
# <text text-anchor="start" x="510.88" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(3) </text>
# <text text-anchor="start" x="528.88" y="-29.57" font-family="Times,serif" font-size="14.00">Bus</text>
# </g>
#
# <g id="node5" class="node">
# <title>4</title>
# <ellipse fill="white" stroke="black" cx="408" cy="-34" rx="67.53" ry="18"></ellipse>
# <text text-anchor="start" x="365.25" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(4) </text>
# <text text-anchor="start" x="383.25" y="-29.57" font-family="Times,serif" font-size="14.00">Light Rail</text>
# </g>
#
# <g id="edge4" class="edge">
# <title>5-&gt;3</title>
# <path fill="none" stroke="black" d="M438.47,-87.52C456.42,-77.22 479.12,-64.2 497.42,-53.69"></path>
# <polygon fill="black" stroke="black" points="498.88,-56.32 505.81,-48.31 495.39,-50.25 498.88,-56.32"></polygon>
# </g>
#
# <g id="edge5" class="edge">
# <title>5-&gt;4</title>
# <path fill="none" stroke="black" d="M408,-87.7C408,-80.24 408,-71.32 408,-62.97"></path>
# <polygon fill="black" stroke="black" points="411.5,-63.1 408,-53.1 404.5,-63.1 411.5,-63.1"></polygon>
# </g>
# </g>
# </svg></div>

# %%
t._root_id
# Out:
# 0

# %% [markdown]
# 公共交通备选方案的效用方程包括一个共同的的未观察到的部分，表示为$\varepsilon_{PT}$。

# %% [markdown]
# $$
# {U_{DA}}={V_{DA}}+{\varepsilon_{DA}}\\{U_{SR}}={V_{SR}}+{\varepsilon_{SR}}\\{U_{Bus}}={V_{Bus}}+{\varepsilon_{PT}}+{\varepsilon_{Bus}}\\{U_{LTR}}={V_{LTR}}+{\varepsilon_{PT}}+{\varepsilon_{LTR}}
# $$

# %% [markdown]
# 独自驾驶和拼车的未观察部分是分布是：
#
# $$
# {\varepsilon_{DA}},{\varepsilon_{SR}}\sim G(0,1)
# $$

# %% [markdown]
# 巴士和轻轨的未观察部分被分为两个组成部分。巴士和轻轨的不同组成部分分别由具有方差参数$\mu_{PT}$的独立同分布的Gumbel随机变量表示。
#
# $$
# {\varepsilon_{Bus}},{\varepsilon_{LTR}}\sim G(0,{\mu_{PT}})
# $$

# %% [markdown]
# 共享的组成部分$\varepsilon_{PT}$的分布是这样的，使得两个分布的和为Gumbel(0, 1)，即：
#
# $$
# \begin{array}{l}
# \varepsilon_{PT}+{\varepsilon_{Bus}}\sim G(0,1)\\
# {\varepsilon_{PT}}+{\varepsilon_{LTR}}\sim G(0,1)
# \end{array}
# $$

# %% [markdown]
# 为确保不同组成部分的方差小于或等于总误差方差，$\mu_{PT}$ 必须介于0和1之间

# %% [markdown]
# 这些假设用于推导基于效用最大化的在这四个备选方案中进行选择的嵌套Logit模型。
#
#
# 我们可以将这个问题描述为存在两个层次的选择：在独自驾驶、拼车和公共交通之间进行边际选择，以及在选择公共交通后在巴士和轻轨之间进行条件选择。然而，NL结构中不能推断出任何行为选择序列。
#
#
# 首先，考虑巴士和轻轨之间的条件选择：
#
# $$
# \begin{align}
# P_{Bus|PT}	&=\Pr\left[{{U_{BUS}}\ge{U_{LTR}}}\right]\\
# 	&=\Pr\left[{{V_{BUS}}+{\varepsilon_{PT}}+{\varepsilon_{BUS}}\le{V_{LTR}}+{\varepsilon_{PT}}+{\varepsilon_{LTR}}}\right]\\
# 	&=\Pr\left[{{V_{BUS}}+{\varepsilon_{BUS}}\ge{V_{LTR}}+{\varepsilon_{LTR}}}\right]\\
# 	&=\Pr\left[{{\varepsilon_{LTR}}\le{V_{BUS}}-{V_{LTR}}+{\varepsilon_{BUS}}}\right]
# \end{align}
# $$

# %% [markdown]
# 由于${\varepsilon_{bus}}$和$\varepsilon_{LTR}$是独立同分布的Gumbel(0,$\mu_{PT}$)随机变量，
#
# $$
# {P_{Bus|PT}}=\frac{{\exp\left({{V_{Bus}}/{\mu_{PT}}}\right)}}{{\sum\limits _{PTM=Bus,LTR}{\exp\left({{V_{PTM}}/{\mu_{PT}}}\right)}}}
# $$
#
# 类似地，对于在选择公共交通后选择轻轨的概率也是如此。

# %% [markdown]
# 在这个表达式中，效用参数的估计仅仅与$\beta_{k}/\mu_{PT}$的范围有关。

# %% [markdown]
# 接下来，考虑独自驾驶、拼车和公共交通之间的边际选择：
# $$
# \begin{align}
# P_{DA}	&=	\Pr\left[{{U_{DA}}\ge{U_{SR}},{U_{Bus}},{U_{LTR}}}\right]\\
# 	&=	\Pr\left[{{U_{DA}}\ge{U_{SR}},\max\left\{ {{U_{Bus}},{U_{LTR}}}\right\} }\right]
# \end{align}
# $$

# %% [markdown]
# 回想一下，两个独立同分布的Gumbel变量的最大值是一个具有位置参数等于原始位置参数的指数之和的Gumbel变量，我们可以用$U_{PT}$替换公共交通工具的效用中的最大化表达式，$U_{PT}$是公共交通方式集合的效用，其分布为
#
# $$
# G(0,{\mu^{PTM}})
# $$

# %% [markdown]
# 也就是说,
#
# $$
# \begin{array}{l}
# {U_{PT}}=\max\left\{ {{U_{Bus}},{U_{LTR}}}\right\} =\mu_{PT}\log\left({\exp\left({{V_{Bus}}/\mu_{PT}}\right)+\exp\left(V_{LTR}/\mu_{PT}\right)}\right)+{\varepsilon_{PT}}+{\varepsilon_{PTM}}\\
# {U_{PT}}=\max\left\{ {{U_{Bus}},{U_{LTR}}}\right\} =\mu_{PT}{\Gamma_{PT}}+\varepsilon_{PT}^{*}
# \end{array}
# $$
#
# 其中 $\Gamma_{PT}=\log\left({\exp\left({{V_{Bus}}/\mu_{PT}}\right)+\exp\left(V_{LTR}/\mu_{PT}\right)}\right)$.

# %% [markdown]
# - 因此,
#
# $$
# \begin{array}{l}
# P(DA)=\frac{{\exp({V_{DA}})}}{{\exp({V_{DA}})+\exp({V_{SR}})+\exp\left({\mu_{PT}{\Gamma_{PT}}}\right)}}\\
# P(SR)=\frac{{\exp({V_{SR}})}}{{\exp({V_{DA}})+\exp({V_{SR}})+\exp\left({\mu_{PT}{\Gamma_{PT}}}\right)}}\\
# P(PT)=\frac{{\exp\left({\mu_{PT}{\Gamma_{PT}}}\right)}}{\begin{array}{l}
# \exp({V_{DA}})+\exp({V_{SR}})+\exp\left({\mu_{PT}{\Gamma_{PT}}}\right)\end{array}}
# \end{array}
# $$

# %% [markdown]
# 条件选择模型的估计包括对${\mu_{PT}}$进行估计。通过将条件模型中的估计结果乘以边际模型中估计的尺度参数${\mu_{PT}}$，可以得到一致的参数估计结果，用于条件选择模型中的巴士和轻轨之间的比较。

# %% [markdown]
# ### 嵌套Logit结构的统计检验
# 采用嵌套Logit模型意味着拒绝多项Logit模型（MNL）。还可以对任何嵌套Logit模型与简化的嵌套Logit模型进行检验，简化模型是初始模型的简化形式。

# %% [markdown]
# #### 全嵌套结构检验
#
# 我们可以使用标准的统计检验来检验多项Logit（MNL）模型是否是真实模型，因为嵌套Logit模型是多项Logit模型的推广。对于多个嵌套集的情况，假设多项Logit模型是真实模型等价于假设所有的logsum参数都等于1。
#
# 使用似然比检验（卡方检验或$\chi^2$）来比较嵌套Logit模型与等价的多项Logit模型，自由度等于logsum参数的数量。

# %% [markdown]
# #### 单个嵌套检验
#
# 要测试单个logsum参数是否显著，可以使用$t$统计量。
#
# 与效用函数中的$\beta$参数不同，logsum参数的默认"零"值为1.0。对于位于根节点下的嵌套，我们可以直接与1进行比较
#
# $$
# \mathrm{t-statistic}=\frac{\hat{\mu}_{k}-1}{s_{k}}
# $$
#
# 其中，$\hat{\mu}{k}$是嵌套$k$的logsum参数的估计值，1是被检验的假设值，$s{k}$是参数估计的标准误差。

# %% [markdown]
# 对于其他嵌套，我们需要将其与上层嵌套的logsum参数值进行比较，而不是与1进行比较。
#
# $$
# \mathrm{t-statistic}=\frac{\hat{\mu}_{k}-\hat{\mu}_{j}}{\sqrt{s_{k}^{2}+s_{j}^{2}-2s_{k,j}}}
# $$
#
# 其中：
#
# - $\hat{\theta}_{k}$是包含在嵌套$j$下的嵌套$k$的logsum参数的估计值，
# - $\hat{\theta}_{j}$是嵌套$j$的logsum参数的估计值，
# - $s_{k}^{2}$是包含在嵌套$j$下的嵌套$k$的logsum参数的误差方差，
# - $s_{j}^{2}$是嵌套$j$的logsum参数的误差方差，以及
# - $s_{k,j}$是两个logsum参数的误差协方差。
#
# 重要的是要注意，这些不一定是所有计算机程序报告的测试值，其中许多程序仅对零或一的零假设应用测试。

# %% [markdown]
# ### Multiple Nests
#
# Extension of above results is that the structural effect for alternatives
# which are not in any common nest is the same as for the MNL.
# Note: it is not necessary for the logsum parameters to be equal for different nests.

# %%
t = NestingTree()
da = t.new_node(name='Drive Alone')
sr = t.new_node(name='Shared Ride')
bus = t.new_node(name='Bus')
ltr = t.new_node(name='Light Rail')
tr = t.new_node(name='Transit', children=[bus,ltr])
ca = t.new_node(name='Car', children=[da,sr])
t
# Out:
# <div xmlns="http://www.w3.org/2000/svg"><svg width="590pt" height="204pt" viewBox="0.00 0.00 590.00 204.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 200)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-200 586,-200 586,4 -4,4"></polygon>
# <g id="clust1" class="cluster">
# <title>cluster_elemental</title>
# <path fill="lightgrey" stroke="white" d="M20,-8C20,-8 562,-8 562,-8 568,-8 574,-14 574,-20 574,-20 574,-48 574,-48 574,-54 568,-60 562,-60 562,-60 20,-60 20,-60 14,-60 8,-54 8,-48 8,-48 8,-20 8,-20 8,-14 14,-8 20,-8"></path>
# </g>
#
# <g id="node1" class="node">
# <title>0</title>
# <polygon fill="none" stroke="black" points="242,-172.44 269,-160 296,-172.44 295.97,-192.56 242.03,-192.56 242,-172.44"></polygon>
# <text text-anchor="middle" x="269" y="-172.57" font-family="Times,serif" font-size="14.00">0</text>
# </g>
#
# <g id="node6" class="node">
# <title>5</title>
# <path fill="none" stroke="black" d="M234.62,-124C234.62,-124 177.38,-124 177.38,-124 171.38,-124 165.38,-118 165.38,-112 165.38,-112 165.38,-100 165.38,-100 165.38,-94 171.38,-88 177.38,-88 177.38,-88 234.62,-88 234.62,-88 240.62,-88 246.62,-94 246.62,-100 246.62,-100 246.62,-112 246.62,-112 246.62,-118 240.62,-124 234.62,-124"></path>
# <text text-anchor="start" x="173.38" y="-101.58" font-family="Times,serif" font-size="9.00" fill="#999999">(5) </text>
# <text text-anchor="start" x="191.38" y="-101.58" font-family="Times,serif" font-size="14.00">Transit</text>
# </g>
#
# <g id="edge1" class="edge">
# <title>0-&gt;5</title>
# <path fill="none" stroke="black" d="M258.03,-164.81C249.99,-155.88 238.8,-143.45 228.86,-132.4"></path>
# <polygon fill="black" stroke="black" points="231.86,-130.39 222.57,-125.3 226.66,-135.07 231.86,-130.39"></polygon>
# </g>
#
# <g id="node7" class="node">
# <title>6</title>
# <path fill="none" stroke="black" d="M347.12,-124C347.12,-124 316.88,-124 316.88,-124 310.88,-124 304.88,-118 304.88,-112 304.88,-112 304.88,-100 304.88,-100 304.88,-94 310.88,-88 316.88,-88 316.88,-88 347.12,-88 347.12,-88 353.12,-88 359.12,-94 359.12,-100 359.12,-100 359.12,-112 359.12,-112 359.12,-118 353.12,-124 347.12,-124"></path>
# <text text-anchor="start" x="312.88" y="-101.58" font-family="Times,serif" font-size="9.00" fill="#999999">(6) </text>
# <text text-anchor="start" x="330.88" y="-101.58" font-family="Times,serif" font-size="14.00">Car</text>
# </g>
#
# <g id="edge2" class="edge">
# <title>0-&gt;6</title>
# <path fill="none" stroke="black" d="M279.97,-164.81C288.01,-155.88 299.2,-143.45 309.14,-132.4"></path>
# <polygon fill="black" stroke="black" points="311.34,-135.07 315.43,-125.3 306.14,-130.39 311.34,-135.07"></polygon>
# </g>
#
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="white" stroke="black" cx="494" cy="-34" rx="72.02" ry="18"></ellipse>
# <text text-anchor="start" x="447.88" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(1) </text>
# <text text-anchor="start" x="465.88" y="-29.57" font-family="Times,serif" font-size="14.00">Drive Alone</text>
# </g>
#
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="white" stroke="black" cx="332" cy="-34" rx="72.02" ry="18"></ellipse>
# <text text-anchor="start" x="285.88" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(2) </text>
# <text text-anchor="start" x="303.88" y="-29.57" font-family="Times,serif" font-size="14.00">Shared Ride</text>
# </g>
#
# <g id="node4" class="node">
# <title>3</title>
# <ellipse fill="white" stroke="black" cx="206" cy="-34" rx="36.09" ry="18"></ellipse>
# <text text-anchor="start" x="186.88" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(3) </text>
# <text text-anchor="start" x="204.88" y="-29.57" font-family="Times,serif" font-size="14.00">Bus</text>
# </g>
#
# <g id="node5" class="node">
# <title>4</title>
# <ellipse fill="white" stroke="black" cx="84" cy="-34" rx="67.53" ry="18"></ellipse>
# <text text-anchor="start" x="41.25" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(4) </text>
# <text text-anchor="start" x="59.25" y="-29.57" font-family="Times,serif" font-size="14.00">Light Rail</text>
# </g>
#
# <g id="edge3" class="edge">
# <title>5-&gt;3</title>
# <path fill="none" stroke="black" d="M206,-87.7C206,-80.24 206,-71.32 206,-62.97"></path>
# <polygon fill="black" stroke="black" points="209.5,-63.1 206,-53.1 202.5,-63.1 209.5,-63.1"></polygon>
# </g>
#
# <g id="edge4" class="edge">
# <title>5-&gt;4</title>
# <path fill="none" stroke="black" d="M175.53,-87.52C158.97,-78.02 138.38,-66.2 120.92,-56.18"></path>
# <polygon fill="black" stroke="black" points="123,-52.77 112.58,-50.83 119.52,-58.84 123,-52.77"></polygon>
# </g>
#
# <g id="edge5" class="edge">
# <title>6-&gt;1</title>
# <path fill="none" stroke="black" d="M359.48,-93.13C384.03,-82.52 420.45,-66.78 449.2,-54.36"></path>
# <polygon fill="black" stroke="black" points="450.23,-57.29 458.02,-50.11 447.45,-50.87 450.23,-57.29"></polygon>
# </g>
#
# <g id="edge6" class="edge">
# <title>6-&gt;2</title>
# <path fill="none" stroke="black" d="M332,-87.7C332,-80.24 332,-71.32 332,-62.97"></path>
# <polygon fill="black" stroke="black" points="335.5,-63.1 332,-53.1 328.5,-63.1 335.5,-63.1"></polygon>
# </g>
# </g>
# </svg></div>

# %% [markdown]
# Note that it is not necessary for the logsum parameters $\mu_{Transit}$ and $\mu_{Car}$ to be the same for the
# Transit and Car nests. However, both must meet the same original requirements: values greater than 0 and less than or equal to 1.

# %% [markdown]
# #### Hierarchical Nests
#
# We can also write the NL model with one nest inside another nest.

# %%
t = NestingTree()
da = t.new_node(name='Drive Alone')
sr = t.new_node(name='Shared Ride')
bus = t.new_node(name='Bus')
ltr = t.new_node(name='Light Rail')
tr = t.new_node(name='Transit', children=[bus,ltr])
sh = t.new_node(name='Shared', children=[tr,sr])
t
# Out:
# <div xmlns="http://www.w3.org/2000/svg"><svg width="590pt" height="276pt" viewBox="0.00 0.00 590.00 276.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 272)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-272 586,-272 586,4 -4,4"></polygon>
# <g id="clust1" class="cluster">
# <title>cluster_elemental</title>
# <path fill="lightgrey" stroke="white" d="M20,-8C20,-8 562,-8 562,-8 568,-8 574,-14 574,-20 574,-20 574,-48 574,-48 574,-54 568,-60 562,-60 562,-60 20,-60 20,-60 14,-60 8,-54 8,-48 8,-48 8,-20 8,-20 8,-14 14,-8 20,-8"></path>
# </g>
#
# <g id="node1" class="node">
# <title>0</title>
# <polygon fill="none" stroke="black" points="142,-244.44 169,-232 196,-244.44 195.97,-264.56 142.03,-264.56 142,-244.44"></polygon>
# <text text-anchor="middle" x="169" y="-244.57" font-family="Times,serif" font-size="14.00">0</text>
# </g>
#
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="white" stroke="black" cx="88" cy="-34" rx="72.02" ry="18"></ellipse>
# <text text-anchor="start" x="41.88" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(1) </text>
# <text text-anchor="start" x="59.88" y="-29.57" font-family="Times,serif" font-size="14.00">Drive Alone</text>
# </g>
#
# <g id="edge1" class="edge">
# <title>0-&gt;1</title>
# <path fill="none" stroke="black" d="M163.43,-234.29C150,-198.8 115.64,-108.01 98.31,-62.25"></path>
# <polygon fill="black" stroke="black" points="101.31,-61.27 94.49,-53.16 94.76,-63.75 101.31,-61.27"></polygon>
# </g>
#
# <g id="node7" class="node">
# <title>6</title>
# <path fill="none" stroke="black" d="M275.25,-196C275.25,-196 224.75,-196 224.75,-196 218.75,-196 212.75,-190 212.75,-184 212.75,-184 212.75,-172 212.75,-172 212.75,-166 218.75,-160 224.75,-160 224.75,-160 275.25,-160 275.25,-160 281.25,-160 287.25,-166 287.25,-172 287.25,-172 287.25,-184 287.25,-184 287.25,-190 281.25,-196 275.25,-196"></path>
# <text text-anchor="start" x="220.75" y="-173.57" font-family="Times,serif" font-size="9.00" fill="#999999">(6) </text>
# <text text-anchor="start" x="238.75" y="-173.57" font-family="Times,serif" font-size="14.00">Shared</text>
# </g>
#
# <g id="edge2" class="edge">
# <title>0-&gt;6</title>
# <path fill="none" stroke="black" d="M182.01,-237.75C192.75,-228.47 208.38,-214.97 221.94,-203.25"></path>
# <polygon fill="black" stroke="black" points="223.78,-205.42 229.05,-196.24 219.2,-200.13 223.78,-205.42"></polygon>
# </g>
#
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="white" stroke="black" cx="250" cy="-34" rx="72.02" ry="18"></ellipse>
# <text text-anchor="start" x="203.88" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(2) </text>
# <text text-anchor="start" x="221.88" y="-29.57" font-family="Times,serif" font-size="14.00">Shared Ride</text>
# </g>
#
# <g id="node4" class="node">
# <title>3</title>
# <ellipse fill="white" stroke="black" cx="530" cy="-34" rx="36.09" ry="18"></ellipse>
# <text text-anchor="start" x="510.88" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(3) </text>
# <text text-anchor="start" x="528.88" y="-29.57" font-family="Times,serif" font-size="14.00">Bus</text>
# </g>
#
# <g id="node5" class="node">
# <title>4</title>
# <ellipse fill="white" stroke="black" cx="408" cy="-34" rx="67.53" ry="18"></ellipse>
# <text text-anchor="start" x="365.25" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(4) </text>
# <text text-anchor="start" x="383.25" y="-29.57" font-family="Times,serif" font-size="14.00">Light Rail</text>
# </g>
#
# <g id="node6" class="node">
# <title>5</title>
# <path fill="none" stroke="black" d="M436.62,-124C436.62,-124 379.38,-124 379.38,-124 373.38,-124 367.38,-118 367.38,-112 367.38,-112 367.38,-100 367.38,-100 367.38,-94 373.38,-88 379.38,-88 379.38,-88 436.62,-88 436.62,-88 442.62,-88 448.62,-94 448.62,-100 448.62,-100 448.62,-112 448.62,-112 448.62,-118 442.62,-124 436.62,-124"></path>
# <text text-anchor="start" x="375.38" y="-101.58" font-family="Times,serif" font-size="9.00" fill="#999999">(5) </text>
# <text text-anchor="start" x="393.38" y="-101.58" font-family="Times,serif" font-size="14.00">Transit</text>
# </g>
#
# <g id="edge3" class="edge">
# <title>5-&gt;3</title>
# <path fill="none" stroke="black" d="M438.47,-87.52C456.42,-77.22 479.12,-64.2 497.42,-53.69"></path>
# <polygon fill="black" stroke="black" points="498.88,-56.32 505.81,-48.31 495.39,-50.25 498.88,-56.32"></polygon>
# </g>
#
# <g id="edge4" class="edge">
# <title>5-&gt;4</title>
# <path fill="none" stroke="black" d="M408,-87.7C408,-80.24 408,-71.32 408,-62.97"></path>
# <polygon fill="black" stroke="black" points="411.5,-63.1 408,-53.1 404.5,-63.1 411.5,-63.1"></polygon>
# </g>
#
# <g id="edge6" class="edge">
# <title>6-&gt;2</title>
# <path fill="none" stroke="black" d="M250,-159.59C250,-135.5 250,-91.75 250,-63.03"></path>
# <polygon fill="black" stroke="black" points="253.5,-63.11 250,-53.11 246.5,-63.11 253.5,-63.11"></polygon>
# </g>
#
# <g id="edge5" class="edge">
# <title>6-&gt;5</title>
# <path fill="none" stroke="black" d="M287.44,-160.41C308.75,-150.97 335.69,-139.04 358.7,-128.84"></path>
# <polygon fill="black" stroke="black" points="359.89,-131.7 367.62,-124.45 357.06,-125.3 359.89,-131.7"></polygon>
# </g>
# </g>
# </svg></div>

# %% [markdown]
# When a nest is inside another nest, the entire structure repeats itself inside the utility of the middle nest.
#
# So, the variance restrictions will still apply: variance inside the lower nest must not exceed variance at the higher levels.  We can conceptualize this by writing out utility functions:
#
# $$
# {U_{DA}}={V_{DA}}+{\varepsilon_{DA}}\\
# {U_{SR}}={V_{SR}}+{\varepsilon_{Share}}+{\varepsilon_{SR}}\\
# {U_{Bus}}={V_{Bus}}+{\varepsilon_{Share}}+{\varepsilon_{PT}}+{\varepsilon_{Bus}}\\
# {U_{LTR}}={V_{LTR}}+{\varepsilon_{Share}}+{\varepsilon_{PT}}+{\varepsilon_{LTR}}
# $$

# %% [markdown]
# The unobserved components of bus and light rail are divided into *three* components. The distinct components for bus and light rail are represented by independent and identically distributed Gumbel random variables with variance parameter, $\mu_{PT}$
#
# $$
# {\varepsilon_{Bus}},{\varepsilon_{LTR}}\sim G(0,{\mu_{PT}})
# $$

# %% [markdown]
# The Transit common component, $\varepsilon_{PT}$, is distributed such that the sum of it and the lower level distributions is Gumbel(0, $\mu_{Share}$); that is,
#
# $$
# \begin{array}{l}
# \varepsilon_{PT}+{\varepsilon_{Bus}}\sim G(0,\mu_{Share})\\
# {\varepsilon_{PT}}+{\varepsilon_{LTR}}\sim G(0,\mu_{Share})
# \end{array}
# $$

# %% [markdown]
# The $\varepsilon_{SR}$ term has the same distribution, but just by itself.
#
# $$
# \varepsilon_{SR}\sim G(0,{\mu_{Share}})
# $$

# %% [markdown]
# The higher level common component, $\varepsilon_{Share}$, is distributed such that the sum of it and the lower level distributions is Gumbel(0, 1); that is,
#
# $$
# \begin{array}{rl}
# \varepsilon_{Share}+\varepsilon_{PT}+{\varepsilon_{Bus}}&\sim G(0,1)\\
# \varepsilon_{Share}+{\varepsilon_{PT}}+{\varepsilon_{LTR}}&\sim G(0,1)\\
# \varepsilon_{Share}+{\varepsilon_{SR}}&\sim G(0,1)
# \end{array}
# $$

# %% [markdown]
# All of the detailed error components here are independent from each other,
# so that the variance of the totals must be increasing as we work our way
# up the nesting tree.

# %% [markdown]
# Thus, the logsum parameter of the lower (smaller, tighter) nest must be less than the logsum parameter of the higher (bigger, looser) nest:
#
# $$
# 0 < \mu_{PT} \le \mu_{Share} \le 1
# $$

# %% [markdown]
# ### Different Nested Logit Models

# %% [markdown]
# The literature includes reference to and description of two different logit models
# which appear to similar but are different in important ways. It is important to be
# aware of these different models to avoid confusion and errors.

# %% [markdown]
# The first of these is the *McFadden* model described above which is referred to as the *Utility Maximization Nested Logit* (UMNL) model.
#
#
# $$
# \begin{array}{rl}
# P(DA)&=\frac{{\exp({V_{DA}})}}{{\exp({V_{DA}})+\exp({V_{SR}})+\exp\left({\mu_{PT}{\Gamma_{PT}}}\right)}}\\
# P(SR)&=\frac{{\exp({V_{SR}})}}{{\exp({V_{DA}})+\exp({V_{SR}})+\exp\left({\mu_{PT}{\Gamma_{PT}}}\right)}}\\
# P(PT)&=\frac{{\exp\left({\mu_{PT}{\Gamma_{PT}}}\right)}}{
# \exp({V_{DA}})+\exp({V_{SR}})+\exp\left({\mu_{PT}{\Gamma_{PT}}}\right)}\\
# \Gamma_{PT}&=\log\left({\exp\left({{V_{Bus}}/\mu_{PT}}\right)+\exp\left(V_{LTR}/\mu_{PT}\right)}\right)\\
# {P({Bus|PT})}&=\frac{{\exp\left({{V_{Bus}}/{\mu_{PT}}}\right)}}
# {
# {\exp\left({{V_{Bus}}/\mu_{PT}}\right)+\exp\left(V_{LTR}/\mu_{PT}\right)}
# }\\
# {P({LTR|PT})}&=\frac{{\exp\left({{V_{LTR}}/{\mu_{PT}}}\right)}}
# {
# {\exp\left({{V_{Bus}}/\mu_{PT}}\right)+\exp\left(V_{LTR}/\mu_{PT}\right)}
# }
# \end{array}
# $$

# %% [markdown]
# - An important feature of these equations is that the logsum parameter, $\mu_{PT}$,
#   appears in the denominator of the conditional utility for all the modes in the nest.
# - The implication of this is that the utility function parameters $\beta$ have a common scale independent of the structure of the tree or where they appear in the tree.
# - Further, if the number of modes in the nest is reduced to one, the utility in the marginal model will be identically equal to the utility for the remaining alternative, as expected.

# %% [markdown]
# An alternative model, the *Non-Normalized Nested Logit* (NNNL), popularized by Andrew Daly and incorporated in some estimation software (notably, "Alogit") as the default, excludes the logsum parameter from the conditional utility functions.
#
# $$
# \begin{array}{rl}
# P(DA)&=\frac{{\exp({V_{DA}})}}{{\exp({V_{DA}})+\exp({V_{SR}})+\exp\left({\mu_{PT}{\Gamma_{PT}}}\right)}}\\
# P(SR)&=\frac{{\exp({V_{SR}})}}{{\exp({V_{DA}})+\exp({V_{SR}})+\exp\left({\mu_{PT}{\Gamma_{PT}}}\right)}}\\
# P(PT)&=\frac{{\exp\left({\mu_{PT}{\Gamma_{PT}}}\right)}}{
# \exp({V_{DA}})+\exp({V_{SR}})+\exp\left({\mu_{PT}{\Gamma_{PT}}}\right)}\\
# \Gamma_{PT}&=\log\left({\exp\left({{V_{Bus}}}\right)+\exp\left(V_{LTR}\right)}\right)\\
# {P({Bus|PT})}&=\frac{{\exp\left({{V_{Bus}}}\right)}}
# {
# {\exp\left({{V_{Bus}}}\right)+\exp\left(V_{LTR}\right)}
# }\\
# {P({LTR|PT})}&=\frac{{\exp\left({{V_{LTR}}}\right)}}
# {
# {\exp\left({{V_{Bus}}}\right)+\exp\left(V_{LTR}\right)}
# }
# \end{array}
# $$
#
#
# This apparently minor change dramatically changes the properties of the model.

# %% [markdown]
# - Most importantly, it is no longer automatically consistent with utility maximization.
# - Further, it results in different scaling of the utility function across alternatives,
#   which impedes the interpretation of these parameters.
# - The NNNL model is consistent with utility maximization only if
#     - the product of all the logsum parameters between the root and each elemental alternative are equal, or,
#     - there are never decision makers who face a choice of alternatives across different nests, or
#     - there are no $\beta$ parameters that appear in the utility functions of alternatives across different nests.
# - On the plus side, the gradient of the log likelihood with respect to the model
#   parameters is slightly easier to compute for the NNNL model.

# %% [markdown]
# If you are stuck using a NNNL model, you can force it into a UMNL by appropriate normalization of the tree structure. The modification consists of introducing dummy nodes and branches (one branch per node) with restrictions on the logsum parameters to ensure that the scaling effect is identical across all elemental alternatives.
#
# The graph below shows such a normalized tree network.  The logsum $\mu$ parameters for nodes "Shared" and "Dummy-2" must be equal, and the logsum $\mu$ parameters for the nodes "Transit", "Dummy-0", and "Dummy-1" must all be equal.

# %%
t = NestingTree()
da = t.new_node(name='Drive Alone')
sr = t.new_node(name='Shared Ride')
bus = t.new_node(name='Bus')
ltr = t.new_node(name='Light Rail')
tr = t.new_node(name='Transit', children=[bus,ltr])
du0 = t.new_node(name='Dummy-0', children=[sr])
sh = t.new_node(name='Shared', children=[tr,du0])
du1 = t.new_node(name='Dummy-1', children=[da])
du2 = t.new_node(name='Dummy-2', children=[du1])
t
# Out:
# <div xmlns="http://www.w3.org/2000/svg"><svg width="590pt" height="276pt" viewBox="0.00 0.00 590.00 276.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 272)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-272 586,-272 586,4 -4,4"></polygon>
# <g id="clust1" class="cluster">
# <title>cluster_elemental</title>
# <path fill="lightgrey" stroke="white" d="M20,-8C20,-8 562,-8 562,-8 568,-8 574,-14 574,-20 574,-20 574,-48 574,-48 574,-54 568,-60 562,-60 562,-60 20,-60 20,-60 14,-60 8,-54 8,-48 8,-48 8,-20 8,-20 8,-14 14,-8 20,-8"></path>
# </g>
#
# <g id="node1" class="node">
# <title>0</title>
# <polygon fill="none" stroke="black" points="353,-244.44 380,-232 407,-244.44 406.97,-264.56 353.03,-264.56 353,-244.44"></polygon>
# <text text-anchor="middle" x="380" y="-244.57" font-family="Times,serif" font-size="14.00">0</text>
# </g>
#
# <g id="node8" class="node">
# <title>7</title>
# <path fill="none" stroke="black" d="M357.25,-196C357.25,-196 306.75,-196 306.75,-196 300.75,-196 294.75,-190 294.75,-184 294.75,-184 294.75,-172 294.75,-172 294.75,-166 300.75,-160 306.75,-160 306.75,-160 357.25,-160 357.25,-160 363.25,-160 369.25,-166 369.25,-172 369.25,-172 369.25,-184 369.25,-184 369.25,-190 363.25,-196 357.25,-196"></path>
# <text text-anchor="start" x="302.75" y="-173.57" font-family="Times,serif" font-size="9.00" fill="#999999">(7) </text>
# <text text-anchor="start" x="320.75" y="-173.57" font-family="Times,serif" font-size="14.00">Shared</text>
# </g>
#
# <g id="edge1" class="edge">
# <title>0-&gt;7</title>
# <path fill="none" stroke="black" d="M370.97,-235.83C365.05,-227.2 357.1,-215.6 349.93,-205.14"></path>
# <polygon fill="black" stroke="black" points="352.43,-203.61 343.89,-197.34 346.66,-207.57 352.43,-203.61"></polygon>
# </g>
#
# <g id="node10" class="node">
# <title>9</title>
# <path fill="none" stroke="black" d="M457.62,-196C457.62,-196 400.38,-196 400.38,-196 394.38,-196 388.38,-190 388.38,-184 388.38,-184 388.38,-172 388.38,-172 388.38,-166 394.38,-160 400.38,-160 400.38,-160 457.62,-160 457.62,-160 463.62,-160 469.62,-166 469.62,-172 469.62,-172 469.62,-184 469.62,-184 469.62,-190 463.62,-196 457.62,-196"></path>
# <text text-anchor="start" x="396.38" y="-173.57" font-family="Times,serif" font-size="9.00" fill="#999999">(9) </text>
# <text text-anchor="start" x="414.38" y="-173.57" font-family="Times,serif" font-size="14.00">Dummy-2</text>
# </g>
#
# <g id="edge2" class="edge">
# <title>0-&gt;9</title>
# <path fill="none" stroke="black" d="M389.22,-235.83C395.26,-227.2 403.38,-215.6 410.7,-205.14"></path>
# <polygon fill="black" stroke="black" points="413.99,-207.54 416.86,-197.34 408.26,-203.53 413.99,-207.54"></polygon>
# </g>
#
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="white" stroke="black" cx="494" cy="-34" rx="72.02" ry="18"></ellipse>
# <text text-anchor="start" x="447.88" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(1) </text>
# <text text-anchor="start" x="465.88" y="-29.57" font-family="Times,serif" font-size="14.00">Drive Alone</text>
# </g>
#
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="white" stroke="black" cx="332" cy="-34" rx="72.02" ry="18"></ellipse>
# <text text-anchor="start" x="285.88" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(2) </text>
# <text text-anchor="start" x="303.88" y="-29.57" font-family="Times,serif" font-size="14.00">Shared Ride</text>
# </g>
#
# <g id="node4" class="node">
# <title>3</title>
# <ellipse fill="white" stroke="black" cx="206" cy="-34" rx="36.09" ry="18"></ellipse>
# <text text-anchor="start" x="186.88" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(3) </text>
# <text text-anchor="start" x="204.88" y="-29.57" font-family="Times,serif" font-size="14.00">Bus</text>
# </g>
#
# <g id="node5" class="node">
# <title>4</title>
# <ellipse fill="white" stroke="black" cx="84" cy="-34" rx="67.53" ry="18"></ellipse>
# <text text-anchor="start" x="41.25" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(4) </text>
# <text text-anchor="start" x="59.25" y="-29.57" font-family="Times,serif" font-size="14.00">Light Rail</text>
# </g>
#
# <g id="node6" class="node">
# <title>5</title>
# <path fill="none" stroke="black" d="M234.62,-124C234.62,-124 177.38,-124 177.38,-124 171.38,-124 165.38,-118 165.38,-112 165.38,-112 165.38,-100 165.38,-100 165.38,-94 171.38,-88 177.38,-88 177.38,-88 234.62,-88 234.62,-88 240.62,-88 246.62,-94 246.62,-100 246.62,-100 246.62,-112 246.62,-112 246.62,-118 240.62,-124 234.62,-124"></path>
# <text text-anchor="start" x="173.38" y="-101.58" font-family="Times,serif" font-size="9.00" fill="#999999">(5) </text>
# <text text-anchor="start" x="191.38" y="-101.58" font-family="Times,serif" font-size="14.00">Transit</text>
# </g>
#
# <g id="edge3" class="edge">
# <title>5-&gt;3</title>
# <path fill="none" stroke="black" d="M206,-87.7C206,-80.24 206,-71.32 206,-62.97"></path>
# <polygon fill="black" stroke="black" points="209.5,-63.1 206,-53.1 202.5,-63.1 209.5,-63.1"></polygon>
# </g>
#
# <g id="edge4" class="edge">
# <title>5-&gt;4</title>
# <path fill="none" stroke="black" d="M175.53,-87.52C158.97,-78.02 138.38,-66.2 120.92,-56.18"></path>
# <polygon fill="black" stroke="black" points="123,-52.77 112.58,-50.83 119.52,-58.84 123,-52.77"></polygon>
# </g>
#
# <g id="node7" class="node">
# <title>6</title>
# <path fill="none" stroke="black" d="M360.62,-124C360.62,-124 303.38,-124 303.38,-124 297.38,-124 291.38,-118 291.38,-112 291.38,-112 291.38,-100 291.38,-100 291.38,-94 297.38,-88 303.38,-88 303.38,-88 360.62,-88 360.62,-88 366.62,-88 372.62,-94 372.62,-100 372.62,-100 372.62,-112 372.62,-112 372.62,-118 366.62,-124 360.62,-124"></path>
# <text text-anchor="start" x="299.38" y="-101.58" font-family="Times,serif" font-size="9.00" fill="#999999">(6) </text>
# <text text-anchor="start" x="317.38" y="-101.58" font-family="Times,serif" font-size="14.00">Dummy-0</text>
# </g>
#
# <g id="edge5" class="edge">
# <title>6-&gt;2</title>
# <path fill="none" stroke="black" d="M332,-87.7C332,-80.24 332,-71.32 332,-62.97"></path>
# <polygon fill="black" stroke="black" points="335.5,-63.1 332,-53.1 328.5,-63.1 335.5,-63.1"></polygon>
# </g>
#
# <g id="edge6" class="edge">
# <title>7-&gt;5</title>
# <path fill="none" stroke="black" d="M300.53,-159.52C284.17,-150.43 263.99,-139.22 246.48,-129.49"></path>
# <polygon fill="black" stroke="black" points="248.51,-126.06 238.07,-124.26 245.11,-132.18 248.51,-126.06"></polygon>
# </g>
#
# <g id="edge7" class="edge">
# <title>7-&gt;6</title>
# <path fill="none" stroke="black" d="M332,-159.7C332,-152.24 332,-143.32 332,-134.97"></path>
# <polygon fill="black" stroke="black" points="335.5,-135.1 332,-125.1 328.5,-135.1 335.5,-135.1"></polygon>
# </g>
#
# <g id="node9" class="node">
# <title>8</title>
# <path fill="none" stroke="black" d="M490.62,-124C490.62,-124 433.38,-124 433.38,-124 427.38,-124 421.38,-118 421.38,-112 421.38,-112 421.38,-100 421.38,-100 421.38,-94 427.38,-88 433.38,-88 433.38,-88 490.62,-88 490.62,-88 496.62,-88 502.62,-94 502.62,-100 502.62,-100 502.62,-112 502.62,-112 502.62,-118 496.62,-124 490.62,-124"></path>
# <text text-anchor="start" x="429.38" y="-101.58" font-family="Times,serif" font-size="9.00" fill="#999999">(8) </text>
# <text text-anchor="start" x="447.38" y="-101.58" font-family="Times,serif" font-size="14.00">Dummy-1</text>
# </g>
#
# <g id="edge8" class="edge">
# <title>8-&gt;1</title>
# <path fill="none" stroke="black" d="M469.91,-87.7C473.48,-79.9 477.77,-70.51 481.74,-61.83"></path>
# <polygon fill="black" stroke="black" points="485.21,-63.65 486.18,-53.1 478.84,-60.74 485.21,-63.65"></polygon>
# </g>
#
# <g id="edge9" class="edge">
# <title>9-&gt;8</title>
# <path fill="none" stroke="black" d="M437.16,-159.7C440.83,-151.9 445.26,-142.51 449.35,-133.83"></path>
# <polygon fill="black" stroke="black" points="452.84,-135.64 453.94,-125.1 446.51,-132.66 452.84,-135.64"></polygon>
# </g>
# </g>
# </svg></div>

# %% [markdown]
# ### Optimization Considerations

# %% [markdown]
# An additional important distinction between the MNL and NL models is that the log likelihood of
# NL models is not guaranteed to be globally concave.  In the abstract, this makes finding a global
# maximum of the log likelihood function "hard".  Fortunately, for any fixed set of values for all
# of the $\mu$ logsum parameters, the log likelihood as a function of the linear-in-parameters
# utility function *is* still globally concave. The dimensionality of the multiple-optima problem
# can therefore be reduced to only the number of logsum parameters. Still, it can be important to
# check multiple different set of values for the logsum parameters to ensure that you are converging
# truely to the global maximum likelihood, and not a local optimum.

# %% [markdown]
# ## Practical Nested Logit

# %% [markdown]
# Given the right tools, the practical application of nested logit models is
# pretty much a simple extension of MNL models.  Most of the hard work in creating
# and estimating these models can be done efficiently with these tools.
#
# To demonstrate the estimation of nested logit models, we'll use the
# same MTC sample dataset used in the previous module, and in the
# [Self Instructing Course in Mode Choice Modeling: Multinomial and Nested Logit Models](http://www.caee.utexas.edu/prof/bhat/courses/lm_draft_060131final-060630.pdf):
#
# > The San Francisco Bay Area work mode choice data set comprises 5029 home-to-work commute trips in the
# > San Francisco Bay Area. The data is drawn from the San Francisco Bay Area Household Travel Survey
# > conducted by the Metropolitan Transportation Commission (MTC) in the spring and fall of 1990. This
# > survey included a one day travel diary for each household member older than five years and detailed
# > individual and household socio-demographic information.

# %%
d = larch.DataFrames(
    ce=pd.read_csv(example_file("MTCwork.csv.gz")).set_index(['casenum','altnum']), 
    ch='chose', 
    crack=True,
    alt_names=['DA', 'SR2', 'SR3+', 'Transit', 'Bike', 'Walk'],
    alt_codes=[1, 2, 3, 4, 5, 6],
)
d.info()
# Out:
# larch.DataFrames:  (not computation-ready)
#   n_cases: 5029
#   n_alts: 6
#   data_ce: 5 variables, 22033 rows
#   data_co: 31 variables
#   data_av: <populated>
#   data_ch: chose

# %% [markdown]
# - Start with Model 17, which we identified as our preferred MNL model structure.

# %%
m = {}

# %%
m[17] = larch.Model.load('./tmp/m17.xlsx')
m[17].dataservice = d
m[17].load_data()
m[17].ordering = (
    ("LoS",".*cost.*",".*time.*",".*dist.*"),
    ("HH","hhinc.*","numveh.*",),
    ("Zone","wkcbd.*","wkempden.*","wkccbd.*"),
    ("ASCs","ASC.*",),
)
# Out:
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided

# %%
m[17].parameter_summary()
# Out:
# <style type="text/css">
# #T_edd88 th {
#   vertical-align: top;
#   text-align: left;
# }
# #T_edd88 td {
#   vertical-align: top;
#   text-align: left;
# }
# #T_edd88_row0_col0, #T_edd88_row0_col1, #T_edd88_row0_col2, #T_edd88_row0_col3, #T_edd88_row0_col4, #T_edd88_row1_col0, #T_edd88_row1_col1, #T_edd88_row1_col2, #T_edd88_row1_col3, #T_edd88_row1_col4, #T_edd88_row2_col0, #T_edd88_row2_col1, #T_edd88_row2_col2, #T_edd88_row2_col3, #T_edd88_row2_col4, #T_edd88_row3_col0, #T_edd88_row3_col1, #T_edd88_row3_col2, #T_edd88_row3_col3, #T_edd88_row3_col4, #T_edd88_row4_col0, #T_edd88_row4_col1, #T_edd88_row4_col2, #T_edd88_row4_col3, #T_edd88_row4_col4, #T_edd88_row5_col0, #T_edd88_row5_col1, #T_edd88_row5_col2, #T_edd88_row5_col3, #T_edd88_row5_col4, #T_edd88_row6_col0, #T_edd88_row6_col1, #T_edd88_row6_col2, #T_edd88_row6_col3, #T_edd88_row6_col4, #T_edd88_row7_col0, #T_edd88_row7_col1, #T_edd88_row7_col2, #T_edd88_row7_col3, #T_edd88_row7_col4, #T_edd88_row8_col0, #T_edd88_row8_col1, #T_edd88_row8_col2, #T_edd88_row8_col3, #T_edd88_row8_col4, #T_edd88_row9_col0, #T_edd88_row9_col1, #T_edd88_row9_col2, #T_edd88_row9_col3, #T_edd88_row9_col4, #T_edd88_row10_col0, #T_edd88_row10_col1, #T_edd88_row10_col2, #T_edd88_row10_col3, #T_edd88_row10_col4, #T_edd88_row11_col0, #T_edd88_row11_col1, #T_edd88_row11_col2, #T_edd88_row11_col3, #T_edd88_row11_col4, #T_edd88_row12_col0, #T_edd88_row12_col1, #T_edd88_row12_col2, #T_edd88_row12_col3, #T_edd88_row12_col4, #T_edd88_row13_col0, #T_edd88_row13_col1, #T_edd88_row13_col2, #T_edd88_row13_col3, #T_edd88_row13_col4, #T_edd88_row14_col0, #T_edd88_row14_col1, #T_edd88_row14_col2, #T_edd88_row14_col3, #T_edd88_row14_col4, #T_edd88_row15_col0, #T_edd88_row15_col1, #T_edd88_row15_col2, #T_edd88_row15_col3, #T_edd88_row15_col4, #T_edd88_row16_col0, #T_edd88_row16_col1, #T_edd88_row16_col2, #T_edd88_row16_col3, #T_edd88_row16_col4, #T_edd88_row17_col0, #T_edd88_row17_col1, #T_edd88_row17_col2, #T_edd88_row17_col3, #T_edd88_row17_col4, #T_edd88_row18_col0, #T_edd88_row18_col1, #T_edd88_row18_col2, #T_edd88_row18_col3, #T_edd88_row18_col4, #T_edd88_row19_col0, #T_edd88_row19_col1, #T_edd88_row19_col2, #T_edd88_row19_col3, #T_edd88_row19_col4, #T_edd88_row20_col0, #T_edd88_row20_col1, #T_edd88_row20_col2, #T_edd88_row20_col3, #T_edd88_row20_col4, #T_edd88_row21_col0, #T_edd88_row21_col1, #T_edd88_row21_col2, #T_edd88_row21_col3, #T_edd88_row21_col4, #T_edd88_row22_col0, #T_edd88_row22_col1, #T_edd88_row22_col2, #T_edd88_row22_col3, #T_edd88_row22_col4, #T_edd88_row23_col0, #T_edd88_row23_col1, #T_edd88_row23_col2, #T_edd88_row23_col3, #T_edd88_row23_col4, #T_edd88_row24_col0, #T_edd88_row24_col1, #T_edd88_row24_col2, #T_edd88_row24_col3, #T_edd88_row24_col4, #T_edd88_row25_col0, #T_edd88_row25_col1, #T_edd88_row25_col2, #T_edd88_row25_col3, #T_edd88_row25_col4 {
#   font-family: monospace;
# }
# </style>
# <table id="T_edd88">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_edd88_level0_col0" class="col_heading level0 col0" >Value</th>
#       <th id="T_edd88_level0_col1" class="col_heading level0 col1" >Std Err</th>
#       <th id="T_edd88_level0_col2" class="col_heading level0 col2" >t Stat</th>
#       <th id="T_edd88_level0_col3" class="col_heading level0 col3" >Signif</th>
#       <th id="T_edd88_level0_col4" class="col_heading level0 col4" >Null Value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Category</th>
#       <th class="index_name level1" >Parameter</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edd88_level0_row0" class="row_heading level0 row0" rowspan="4">LoS</th>
#       <th id="T_edd88_level1_row0" class="row_heading level1 row0" >totcost/hhinc</th>
#       <td id="T_edd88_row0_col0" class="data row0 col0" >-0.0524</td>
#       <td id="T_edd88_row0_col1" class="data row0 col1" > 0.0104</td>
#       <td id="T_edd88_row0_col2" class="data row0 col2" >-5.04</td>
#       <td id="T_edd88_row0_col3" class="data row0 col3" >***</td>
#       <td id="T_edd88_row0_col4" class="data row0 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_edd88_level1_row1" class="row_heading level1 row1" >motor_time</th>
#       <td id="T_edd88_row1_col0" class="data row1 col0" >-0.0202</td>
#       <td id="T_edd88_row1_col1" class="data row1 col1" > 0.00381</td>
#       <td id="T_edd88_row1_col2" class="data row1 col2" >-5.29</td>
#       <td id="T_edd88_row1_col3" class="data row1 col3" >***</td>
#       <td id="T_edd88_row1_col4" class="data row1 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_edd88_level1_row2" class="row_heading level1 row2" >nonmotor_time</th>
#       <td id="T_edd88_row2_col0" class="data row2 col0" >-0.0454</td>
#       <td id="T_edd88_row2_col1" class="data row2 col1" > 0.00577</td>
#       <td id="T_edd88_row2_col2" class="data row2 col2" >-7.88</td>
#       <td id="T_edd88_row2_col3" class="data row2 col3" >***</td>
#       <td id="T_edd88_row2_col4" class="data row2 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_edd88_level1_row3" class="row_heading level1 row3" >ovtt/dist</th>
#       <td id="T_edd88_row3_col0" class="data row3 col0" >-0.133</td>
#       <td id="T_edd88_row3_col1" class="data row3 col1" > 0.0196</td>
#       <td id="T_edd88_row3_col2" class="data row3 col2" >-6.76</td>
#       <td id="T_edd88_row3_col3" class="data row3 col3" >***</td>
#       <td id="T_edd88_row3_col4" class="data row3 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_edd88_level0_row4" class="row_heading level0 row4" rowspan="7">HH</th>
#       <th id="T_edd88_level1_row4" class="row_heading level1 row4" >hhinc#4</th>
#       <td id="T_edd88_row4_col0" class="data row4 col0" >-0.00532</td>
#       <td id="T_edd88_row4_col1" class="data row4 col1" > 0.00198</td>
#       <td id="T_edd88_row4_col2" class="data row4 col2" >-2.69</td>
#       <td id="T_edd88_row4_col3" class="data row4 col3" >**</td>
#       <td id="T_edd88_row4_col4" class="data row4 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_edd88_level1_row5" class="row_heading level1 row5" >hhinc#5</th>
#       <td id="T_edd88_row5_col0" class="data row5 col0" >-0.00864</td>
#       <td id="T_edd88_row5_col1" class="data row5 col1" > 0.00515</td>
#       <td id="T_edd88_row5_col2" class="data row5 col2" >-1.68</td>
#       <td id="T_edd88_row5_col3" class="data row5 col3" ></td>
#       <td id="T_edd88_row5_col4" class="data row5 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_edd88_level1_row6" class="row_heading level1 row6" >hhinc#6</th>
#       <td id="T_edd88_row6_col0" class="data row6 col0" >-0.00599</td>
#       <td id="T_edd88_row6_col1" class="data row6 col1" > 0.00315</td>
#       <td id="T_edd88_row6_col2" class="data row6 col2" >-1.90</td>
#       <td id="T_edd88_row6_col3" class="data row6 col3" ></td>
#       <td id="T_edd88_row6_col4" class="data row6 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_edd88_level1_row7" class="row_heading level1 row7" >numveh#23</th>
#       <td id="T_edd88_row7_col0" class="data row7 col0" >-0.317</td>
#       <td id="T_edd88_row7_col1" class="data row7 col1" > 0.0666</td>
#       <td id="T_edd88_row7_col2" class="data row7 col2" >-4.75</td>
#       <td id="T_edd88_row7_col3" class="data row7 col3" >***</td>
#       <td id="T_edd88_row7_col4" class="data row7 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_edd88_level1_row8" class="row_heading level1 row8" >numveh#4</th>
#       <td id="T_edd88_row8_col0" class="data row8 col0" >-0.947</td>
#       <td id="T_edd88_row8_col1" class="data row8 col1" > 0.118</td>
#       <td id="T_edd88_row8_col2" class="data row8 col2" >-8.00</td>
#       <td id="T_edd88_row8_col3" class="data row8 col3" >***</td>
#       <td id="T_edd88_row8_col4" class="data row8 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_edd88_level1_row9" class="row_heading level1 row9" >numve

# %% [markdown]
# Recreate the constants only model, for comparisons.

# %%
m_c = larch.Model(dataservice=d)
m_c.utility_co[2] = P("ASC_SR2")  
m_c.utility_co[3] = P("ASC_SR3P") 
m_c.utility_co[4] = P("ASC_TRAN") 
m_c.utility_co[5] = P("ASC_BIKE") 
m_c.utility_co[6] = P("ASC_WALK") 
m_c.title = "Constants Only"
# m_c.estimate(); # This can be slow!
m_c.load_data()
m_c.loglike_null()
m_c.maximize_loglike(quiet=True);
# Out:
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided

# %% [markdown]
# Let's also create function that writes a "Value of Time" report table for each model.

# %%
def value_of_time(model):
    c = model['totcost/hhinc'].value / 1.2
    m_ = model

    VoT = pd.DataFrame(
        columns=['% Wage Rate', '$10/hr', '$20/hr', '$40/hr'],
        index=['Non-Motor','IVTT','OVTT @ 1 mile','OVTT @ 5 mile','OVTT @ 10 mile']
    )

    VoT.loc['Non-Motor', '% Wage Rate'] = "{:.2%}".format(m_['nonmotor_time'].value/c)
    VoT.loc['IVTT', '% Wage Rate'] = "{:.2%}".format(m_['motor_time'].value/c)
    for dist in [1,5,10]:
        VoT.loc[f'OVTT @ {dist} mile', '% Wage Rate'] = "{:.2%}".format((m_['ovtt/dist'].value/dist+m_['motor_time'].value)/c)


    for wage in [10,20,40]:
        VoT.loc['Non-Motor', f'${wage}/hr'] = "${:.2f}/hr".format(wage*m_['nonmotor_time'].value/c)
        VoT.loc['IVTT', f'${wage}/hr'] = "${:.2f}/hr".format(wage*m_['motor_time'].value/c)
        for dist in [1,5,10]:
            VoT.loc[f'OVTT @ {dist} mile', f'${wage}/hr'] = "${:.2f}/hr".format(wage*(m_['ovtt/dist'].value/dist+m_['motor_time'].value)/c)
    return VoT

# %%
value_of_time(m[17])
# Out:
#                % Wage Rate     $10/hr     $20/hr      $40/hr
# Non-Motor          104.04%  $10.40/hr  $20.81/hr   $41.62/hr
# IVTT                46.22%   $4.62/hr   $9.24/hr   $18.49/hr
# OVTT @ 1 mile      350.34%  $35.03/hr  $70.07/hr  $140.14/hr
# OVTT @ 5 mile      107.05%  $10.70/hr  $21.41/hr   $42.82/hr
# OVTT @ 10 mile      76.64%   $7.66/hr  $15.33/hr   $30.65/hr

# %% [markdown]
# ### Some Simple Single Nests
#
# - Begin by adding some simple nests to the model.
#     - 18: All motorized modes together
#     - 19: All automobile modes together
#     - 20: All shared ride modes together
#     - 21: All non-motorized modes together

# %%
m[18] = m[17].copy()
m[18].set_values('null')
m[18].title = "Model 18"

# %%
m[18].pf
# Out:
#                value  initvalue  nullvalue  minimum  maximum  holdfast note
# ASC_BIKE         0.0        0.0        0.0     -inf      inf         0       \
# ASC_SR2          0.0        0.0        0.0     -inf      inf         0
# ASC_SR3P         0.0        0.0        0.0     -inf      inf         0
# ASC_TRAN         0.0        0.0        0.0     -inf      inf         0
# ASC_WALK         0.0        0.0        0.0     -inf      inf         0
# hhinc#4          0.0        0.0        0.0     -inf      inf         0
# hhinc#5          0.0        0.0        0.0     -inf      inf         0
# hhinc#6          0.0        0.0        0.0     -inf      inf         0
# motor_time       0.0        0.0        0.0     -inf      inf         0
# nonmotor_time    0.0        0.0        0.0     -inf      inf         0
# numveh#23        0.0        0.0        0.0     -inf      inf         0
# numveh#4         0.0        0.0        0.0     -inf      inf         0
# numveh#5         0.0        0.0        0.0     -inf      inf         0
# numveh#6         0.0        0.0        0.0     -inf      inf         0
# ovtt/dist        0.0        0.0        0.0     -inf      inf         0
# totcost/hhinc    0.0        0.0        0.0     -inf      inf         0
# wkccbd#2         0.0        0.0        0.0     -inf      inf         0
# wkccbd#3         0.0        0.0        0.0     -inf      inf         0
# wkccbd#4         0.0        0.0        0.0     -inf      inf         0
# wkccbd#5         0.0        0.0        0.0     -inf      inf         0
# wkccbd#6         0.0        0.0        0.0     -inf      inf         0
# wkempden#2       0.0        0.0        0.0     -inf      inf         0
# wkempden#3       0.0        0.0        0.0     -inf      inf         0
# wkempden#4       0.0        0.0        0.0     -inf      inf         0
# wkempden#5       0.0        0.0        0.0     -inf      inf         0
# wkempden#6       0.0        0.0        0.0     -inf      inf         0
#
#                 std_err     t_stat  robust_std_err  robust_t_stat
# ASC_BIKE       0.427402  -3.809951        0.486187      -3.349286
# ASC_SR2        0.106124 -17.032011        0.117012     -15.447139
# ASC_SR3P       0.151865 -22.608409        0.155748     -22.044682
# ASC_TRAN       0.247823  -2.761816        0.269013      -2.544264
# ASC_WALK       0.348015   0.197809        0.349258       0.197106
# hhinc#4        0.001977  -2.692723        0.002047      -2.600354
# hhinc#5        0.005154  -1.676899        0.005966      -1.448622
# hhinc#6        0.003149  -1.903989        0.003431      -1.746984
# motor_time     0.003815  -5.292852        0.003898      -5.179039
# nonmotor_time  0.005768  -7.878123        0.005759      -7.890651
# numveh#23      0.066638  -4.754837        0.075615      -4.190393
# numveh#4       0.118299  -8.002163        0.137025      -6.908548
# numveh#5       0.258302  -2.719884        0.309445      -2.270356
# numveh#6       0.169432  -4.264526        0.203311      -3.553915
# ovtt/dist      0.019642  -6.762932        0.024098      -5.512303
# totcost/hhinc  0.010404  -5.037941        0.013343      -3.928394
# wkccbd#2       0.123352   2.106371        0.123381       2.105873
# wkccbd#3       0.191275   5.590223        0.189943       5.629443
# wkccbd#4       0.165697   7.898939        0.158487       8.258267
# wkccbd#5       0.361094   1.354829        0.366472       1.334944
# wkccbd#6       0.252109   0.403344        0.258846       0.392847
# wkempden#2     0.000390   4.041921        0.000413       3.822042
# wkempden#3     0.000452   4.993434        0.000454       4.974246
# wkempden#4     0.000361   8.684341        0.000383       8.177938
# wkempden#5     0.001215   1.587475        0.001175       1.641490
# wkempden#6     0.000742   3.896291        0.000711       4.068690

# %%
m[18].graph
# Out:
# <div xmlns="http://www.w3.org/2000/svg"><svg width="619pt" height="132pt" viewBox="0.00 0.00 619.00 132.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 128)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-128 615,-128 615,4 -4,4"></polygon>
# <g id="clust1" class="cluster">
# <title>cluster_elemental</title>
# <path fill="lightgrey" stroke="white" d="M20,-8C20,-8 591,-8 591,-8 597,-8 603,-14 603,-20 603,-20 603,-48 603,-48 603,-54 597,-60 591,-60 591,-60 20,-60 20,-60 14,-60 8,-54 8,-48 8,-48 8,-20 8,-20 8,-14 14,-8 20,-8"></path>
# </g>
#
# <g id="node1" class="node">
# <title>0</title>
# <polygon fill="none" stroke="black" points="298,-100.44 325,-88 352,-100.44 351.97,-120.56 298.03,-120.56 298,-100.44"></polygon>
# <text text-anchor="middle" x="325" y="-100.58" font-family="Times,serif" font-size="14.00">0</text>
# </g>
#
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="white" stroke="black" cx="563" cy="-34" rx="31.6" ry="18"></ellipse>
# <text text-anchor="start" x="547.25" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(1) </text>
# <text text-anchor="start" x="565.25" y="-29.57" font-family="Times,serif" font-size="14.00">DA</text>
# </g>
#
# <g id="edge1" class="edge">
# <title>0-&gt;1</title>
# <path fill="none" stroke="black" d="M352.28,-101.61C391.1,-96.16 463.99,-83.58 522,-60 526.17,-58.3 530.41,-56.21 534.49,-53.97"></path>
# <polygon fill="black" stroke="black" points="535.83,-56.65 542.66,-48.56 532.27,-50.62 535.83,-56.65"></polygon>
# </g>
#
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="white" stroke="black" cx="477" cy="-34" rx="36.09" ry="18"></ellipse>
# <text text-anchor="start" x="457.88" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(2) </text>
# <text text-anchor="start" x="475.88" y="-29.57" font-family="Times,serif" font-size="14.00">SR2</text>
# </g>
#
# <g id="edge2" class="edge">
# <title>0-&gt;2</title>
# <path fill="none" stroke="black" d="M345.41,-97.19C367.16,-88.68 402.46,-74.36 432,-60 436.16,-57.98 440.48,-55.75 444.72,-53.49"></path>
# <polygon fill="black" stroke="black" points="446.27,-56.08 453.36,-48.21 442.91,-49.94 446.27,-56.08"></polygon>
# </g>
#
# <g id="node4" class="node">
# <title>3</title>
# <ellipse fill="white" stroke="black" cx="382" cy="-34" rx="40.58" ry="18"></ellipse>
# <text text-anchor="start" x="359.5" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(3) </text>
# <text text-anchor="start" x="377.5" y="-29.57" font-family="Times,serif" font-size="14.00">SR3+</text>
# </g>
#
# <g id="edge3" class="edge">
# <title>0-&gt;3</title>
# <path fill="none" stroke="black" d="M335.19,-92.49C342.57,-83.42 352.79,-70.88 361.79,-59.82"></path>
# <polygon fill="black" stroke="black" points="365.08,-62.32 368.68,-52.36 359.65,-57.9 365.08,-62.32"></polygon>
# </g>
#
# <g id="node5" class="node">
# <title>4</title>
# <ellipse fill="white" stroke="black" cx="269" cy="-34" rx="54.06" ry="18"></ellipse>
# <text text-anchor="start" x="236.38" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(4) </text>
# <text text-anchor="start" x="254.38" y="-29.57" font-family="Times,serif" font-size="14.00">Transit</text>
# </g>
#
# <g id="edge4" class="edge">
# <title>0-&gt;4</title>
# <path fill="none" stroke="black" d="M314.99,-92.49C307.84,-83.55 297.98,-71.22 289.22,-60.27"></path>
# <polygon fill="black" stroke="black" points="291.48,-58.5 282.5,-52.88 286.02,-62.87 291.48,-58.5"></polygon>
# </g>
#
# <g id="node6" class="node">
# <title>5</title>
# <ellipse fill="white" stroke="black" cx="156" cy="-34" rx="40.58" ry="18"></ellipse>
# <text text-anchor="start" x="133.5" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(5) </text>
# <text text-anchor="start" x="151.5" y="-29.57" font-family="Times,serif" font-size="14.00">Bike</text>
# </g>
#
# <g id="edge5" class="edge">
# <title>0-&gt;5</title>
# <path fill="none" stroke="black" d="M303.24,-97.52C279.17,-89.08 239.39,-74.61 206,-60 201.2,-57.9 196.19,-55.57 191.29,-53.2"></path>
# <polygon fill="black" stroke="black" points="192.97,-49.64 182.45,-48.36 189.88,-55.92 192.97,-49.64"></polygon>
# </g>
#
# <g id="node7" class="node">
# <title>6</title>
# <ellipse fill="white" stroke="black" cx="57" cy="-34" rx="40.58" ry="18"></ellipse>
# <text text-anchor="start" x="34.5" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(6) </text>
# <text text-anchor="start" x="52.5" y="-29.57" font-family="Times,serif" font-size="14.00">Walk</text>
# </g>
#
# <g id="edge6" class="edge">
# <title>0-&gt;6</title>
# <path fill="none" stroke="black" d="M297.74,-101.8C255.68,-96.33 172.85,-83.44 106,-60 101.02,-58.26 95.91,-56.1 90.96,-53.79"></path>
# <polygon fill="black" stroke="black" points="92.62,-50.21 82.1,-48.93 89.52,-56.49 92.62,-50.21"></polygon>
# </g>
# </g>
# </svg></div>

# %%
m[18].graph.new_node(name="Motorized", parameter="MotorizedParam", children=[1,2,3,4]);

# %%
m[18].graph
# Out:
# <div xmlns="http://www.w3.org/2000/svg"><svg width="619pt" height="204pt" viewBox="0.00 0.00 619.00 204.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 200)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-200 615,-200 615,4 -4,4"></polygon>
# <g id="clust1" class="cluster">
# <title>cluster_elemental</title>
# <path fill="lightgrey" stroke="white" d="M20,-8C20,-8 591,-8 591,-8 597,-8 603,-14 603,-20 603,-20 603,-48 603,-48 603,-54 597,-60 591,-60 591,-60 20,-60 20,-60 14,-60 8,-54 8,-48 8,-48 8,-20 8,-20 8,-14 14,-8 20,-8"></path>
# </g>
#
# <g id="node1" class="node">
# <title>0</title>
# <polygon fill="none" stroke="black" points="129,-172.44 156,-160 183,-172.44 182.97,-192.56 129.03,-192.56 129,-172.44"></polygon>
# <text text-anchor="middle" x="156" y="-172.57" font-family="Times,serif" font-size="14.00">0</text>
# </g>
#
# <g id="node6" class="node">
# <title>5</title>
# <ellipse fill="white" stroke="black" cx="57" cy="-34" rx="40.58" ry="18"></ellipse>
# <text text-anchor="start" x="34.5" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(5) </text>
# <text text-anchor="start" x="52.5" y="-29.57" font-family="Times,serif" font-size="14.00">Bike</text>
# </g>
#
# <g id="edge1" class="edge">
# <title>0-&gt;5</title>
# <path fill="none" stroke="black" d="M146.86,-163.9C130.47,-140.38 95.78,-90.63 74.62,-60.28"></path>
# <polygon fill="black" stroke="black" points="77.12,-58.73 68.53,-52.53 71.37,-62.74 77.12,-58.73"></polygon>
# </g>
#
# <g id="node7" class="node">
# <title>6</title>
# <ellipse fill="white" stroke="black" cx="156" cy="-34" rx="40.58" ry="18"></ellipse>
# <text text-anchor="start" x="133.5" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(6) </text>
# <text text-anchor="start" x="151.5" y="-29.57" font-family="Times,serif" font-size="14.00">Walk</text>
# </g>
#
# <g id="edge2" class="edge">
# <title>0-&gt;6</title>
# <path fill="none" stroke="black" d="M156,-159.59C156,-135.5 156,-91.75 156,-63.03"></path>
# <polygon fill="black" stroke="black" points="159.5,-63.11 156,-53.11 152.5,-63.11 159.5,-63.11"></polygon>
# </g>
#
# <g id="node8" class="node">
# <title>7</title>
# <path fill="none" stroke="black" d="M372.38,-124C372.38,-124 301.62,-124 301.62,-124 295.62,-124 289.62,-118 289.62,-112 289.62,-112 289.62,-100 289.62,-100 289.62,-94 295.62,-88 301.62,-88 301.62,-88 372.38,-88 372.38,-88 378.38,-88 384.38,-94 384.38,-100 384.38,-100 384.38,-112 384.38,-112 384.38,-118 378.38,-124 372.38,-124"></path>
# <text text-anchor="start" x="297.62" y="-105.2" font-family="Times,serif" font-size="9.00" fill="#999999">(7) </text>
# <text text-anchor="start" x="315.62" y="-105.2" font-family="Times,serif" font-size="14.00">Motorized</text>
# <text text-anchor="start" x="300.25" y="-95.95" font-family="Times,serif" font-style="italic" font-size="9.00" fill="#999999">MotorizedParam</text>
# </g>
#
# <g id="edge3" class="edge">
# <title>0-&gt;7</title>
# <path fill="none" stroke="black" d="M176.41,-169.11C201.85,-159.27 246.32,-142.07 282.02,-128.26"></path>
# <polygon fill="black" stroke="black" points="282.77,-131.34 290.84,-124.47 280.25,-124.81 282.77,-131.34"></polygon>
# </g>
#
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="white" stroke="black" cx="337" cy="-34" rx="31.6" ry="18"></ellipse>
# <text text-anchor="start" x="321.25" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(1) </text>
# <text text-anchor="start" x="339.25" y="-29.57" font-family="Times,serif" font-size="14.00">DA</text>
# </g>
#
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="white" stroke="black" cx="251" cy="-34" rx="36.09" ry="18"></ellipse>
# <text text-anchor="start" x="231.88" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(2) </text>
# <text text-anchor="start" x="249.88" y="-29.57" font-family="Times,serif" font-size="14.00">SR2</text>
# </g>
#
# <g id="node4" class="node">
# <title>3</title>
# <ellipse fill="white" stroke="black" cx="554" cy="-34" rx="40.58" ry="18"></ellipse>
# <text text-anchor="start" x="531.5" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(3) </text>
# <text text-anchor="start" x="549.5" y="-29.57" font-family="Times,serif" font-size="14.00">SR3+</text>
# </g>
#
# <g id="node5" class="node">
# <title>4</title>
# <ellipse fill="white" stroke="black" cx="441" cy="-34" rx="54.06" ry="18"></ellipse>
# <text text-anchor="start" x="408.38" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(4) </text>
# <text text-anchor="start" x="426.38" y="-29.57" font-family="Times,serif" font-size="14.00">Transit</text>
# </g>
#
# <g id="edge4" class="edge">
# <title>7-&gt;1</title>
# <path fill="none" stroke="black" d="M337,-87.7C337,-80.24 337,-71.32 337,-62.97"></path>
# <polygon fill="black" stroke="black" points="340.5,-63.1 337,-53.1 333.5,-63.1 340.5,-63.1"></polygon>
# </g>
#
# <g id="edge5" class="edge">
# <title>7-&gt;2</title>
# <path fill="none" stroke="black" d="M315.74,-87.7C304.29,-78.38 290.06,-66.79 277.85,-56.86"></path>
# <polygon fill="black" stroke="black" points="280.36,-53.57 270.39,-49.97 275.94,-59 280.36,-53.57"></polygon>
# </g>
#
# <g id="edge6" class="edge">
# <title>7-&gt;3</title>
# <path fill="none" stroke="black" d="M384.59,-94.86C418.45,-87 464.71,-74.94 504,-60 509.14,-58.04 514.46,-55.73 519.62,-53.31"></path>
# <polygon fill="black" stroke="black" points="520.81,-56.13 528.26,-48.6 517.74,-49.84 520.81,-56.13"></polygon>
# </g>
#
# <g id="edge7" class="edge">
# <title>7-&gt;4</title>
# <path fill="none" stroke="black" d="M362.98,-87.52C376.93,-78.13 394.24,-66.47 409.02,-56.53"></path>
# <polygon fill="black" stroke="black" points="410.49,-59.08 416.83,-50.59 406.58,-53.27 410.49,-59.08"></polygon>
# </g>
# </g>
# </svg></div>

# %%
# m[18].pf.loc[:, 'minimum'] = -10.0
# m[18].pf.loc[:, 'maximum'] = +10.0
m[18].set_cap(10)
m[18].estimate()
# Out:
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# ┣                x: ASC_BIKE        -1.628359
# ┃                   ASC_SR2         -1.807549
# ┃                   ASC_SR3P        -3.433476
# ┃                   ASC_TRAN        -0.684387
# ┃                   ASC_WALK         0.068974
# ┃                   hhinc#4         -0.005324
# ┃                   hhinc#5         -0.008643
# ┃                   hhinc#6         -0.005996
# ┃                   motor_time      -0.020191
# ┃                   nonmotor_time   -0.045449
# ┃                   numveh#23       -0.316823
# ┃                   numveh#4        -0.946587
# ┃                   numveh#5        -0.702508
# ┃                   numveh#6        -0.722470
# ┃                   ovtt/dist       -0.132857
# ┃                   totcost/hhinc   -0.052419
# ┃                   wkccbd#2         0.259818
# ┃                   wkccbd#3         1.069286
# ┃                   wkccbd#4         1.308823
# ┃                   wkccbd#5         0.489278
# ┃                   wkccbd#6         0.101696
# ┃                   wkempden#2       0.001578
# ┃                   wkempden#3       0.002257
# ┃                   wkempden#4       0.003133
# ┃                   wkempden#5       0.001928
# ┃                   wkempden#6       0.002890
# ┃                   dtype: float64
# ┣          loglike: -3444.143381438587
# ┣        d_loglike: ASC_BIKE        -0.000899
# ┃                   ASC_SR2         -0.001020
# ┃                   ASC_SR3P         0.002254
# ┃                   ASC_TRAN         0.003853
# ┃                   ASC_WALK         0.003308
# ┃                   hhinc#4          0.290966
# ┃                   hhinc#5         -0.040205
# ┃                   hhinc#6          0.186513
# ┃                   motor_time       0.129995
# ┃                   nonmotor_time    0.099736
# ┃                   numveh#23        0.000752
# ┃                   numveh#4         0.005391
# ┃                   numveh#5        -0.000676
# ┃                   numveh#6         0.003080
# ┃                   ovtt/dist       -0.011571
# ┃                   totcost/hhinc   -0.023400
# ┃                   wkccbd#2        -0.001148
# ┃                   wkccbd#3         0.001092
# ┃                   wkccbd#4         0.002712
# ┃                   wkccbd#5        -0.000510
# ┃                   wkccbd#6         0.001125
# ┃                   wkempden#2      -0.715311
# ┃                   wkempden#3       1.089924
# ┃                   wkempden#4       0.586763
# ┃                   wkempden#5      -0.249993
# ┃                   wkempden#6       0.357091
# ┃                   dtype: float64
# ┣              nit: 43
# ┣             nfev: 120
# ┣             njev: 43
# ┣           status: 0
# ┣          message: 'Optimization terminated successfully'
# ┣          success: True
# ┣     elapsed_time: datetime.timedelta(seconds=1, microseconds=827273)
# ┣           method: 'slsqp'
# ┣          n_cases: 5029
# ┣ iteration_number: 43
# ┣          logloss: 0.6848565085381958

# %% [markdown]
# Inside a Jupyter notebook, the nesting graph object is shown not as
# a text version of itself but as a graphic, which is helpful to be able
# to see the shape of the nesting network:

# %%
m[18].graph
# Out:
# <div xmlns="http://www.w3.org/2000/svg"><svg width="619pt" height="204pt" viewBox="0.00 0.00 619.00 204.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 200)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-200 615,-200 615,4 -4,4"></polygon>
# <g id="clust1" class="cluster">
# <title>cluster_elemental</title>
# <path fill="lightgrey" stroke="white" d="M20,-8C20,-8 591,-8 591,-8 597,-8 603,-14 603,-20 603,-20 603,-48 603,-48 603,-54 597,-60 591,-60 591,-60 20,-60 20,-60 14,-60 8,-54 8,-48 8,-48 8,-20 8,-20 8,-14 14,-8 20,-8"></path>
# </g>
#
# <g id="node1" class="node">
# <title>0</title>
# <polygon fill="none" stroke="black" points="129,-172.44 156,-160 183,-172.44 182.97,-192.56 129.03,-192.56 129,-172.44"></polygon>
# <text text-anchor="middle" x="156" y="-172.57" font-family="Times,serif" font-size="14.00">0</text>
# </g>
#
# <g id="node6" class="node">
# <title>5</title>
# <ellipse fill="white" stroke="black" cx="57" cy="-34" rx="40.58" ry="18"></ellipse>
# <text text-anchor="start" x="34.5" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(5) </text>
# <text text-anchor="start" x="52.5" y="-29.57" font-family="Times,serif" font-size="14.00">Bike</text>
# </g>
#
# <g id="edge1" class="edge">
# <title>0-&gt;5</title>
# <path fill="none" stroke="black" d="M146.86,-163.9C130.47,-140.38 95.78,-90.63 74.62,-60.28"></path>
# <polygon fill="black" stroke="black" points="77.12,-58.73 68.53,-52.53 71.37,-62.74 77.12,-58.73"></polygon>
# </g>
#
# <g id="node7" class="node">
# <title>6</title>
# <ellipse fill="white" stroke="black" cx="156" cy="-34" rx="40.58" ry="18"></ellipse>
# <text text-anchor="start" x="133.5" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(6) </text>
# <text text-anchor="start" x="151.5" y="-29.57" font-family="Times,serif" font-size="14.00">Walk</text>
# </g>
#
# <g id="edge2" class="edge">
# <title>0-&gt;6</title>
# <path fill="none" stroke="black" d="M156,-159.59C156,-135.5 156,-91.75 156,-63.03"></path>
# <polygon fill="black" stroke="black" points="159.5,-63.11 156,-53.11 152.5,-63.11 159.5,-63.11"></polygon>
# </g>
#
# <g id="node8" class="node">
# <title>7</title>
# <path fill="none" stroke="black" d="M372.38,-124C372.38,-124 301.62,-124 301.62,-124 295.62,-124 289.62,-118 289.62,-112 289.62,-112 289.62,-100 289.62,-100 289.62,-94 295.62,-88 301.62,-88 301.62,-88 372.38,-88 372.38,-88 378.38,-88 384.38,-94 384.38,-100 384.38,-100 384.38,-112 384.38,-112 384.38,-118 378.38,-124 372.38,-124"></path>
# <text text-anchor="start" x="297.62" y="-105.2" font-family="Times,serif" font-size="9.00" fill="#999999">(7) </text>
# <text text-anchor="start" x="315.62" y="-105.2" font-family="Times,serif" font-size="14.00">Motorized</text>
# <text text-anchor="start" x="300.25" y="-95.95" font-family="Times,serif" font-style="italic" font-size="9.00" fill="#999999">MotorizedParam</text>
# </g>
#
# <g id="edge3" class="edge">
# <title>0-&gt;7</title>
# <path fill="none" stroke="black" d="M176.41,-169.11C201.85,-159.27 246.32,-142.07 282.02,-128.26"></path>
# <polygon fill="black" stroke="black" points="282.77,-131.34 290.84,-124.47 280.25,-124.81 282.77,-131.34"></polygon>
# </g>
#
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="white" stroke="black" cx="337" cy="-34" rx="31.6" ry="18"></ellipse>
# <text text-anchor="start" x="321.25" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(1) </text>
# <text text-anchor="start" x="339.25" y="-29.57" font-family="Times,serif" font-size="14.00">DA</text>
# </g>
#
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="white" stroke="black" cx="251" cy="-34" rx="36.09" ry="18"></ellipse>
# <text text-anchor="start" x="231.88" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(2) </text>
# <text text-anchor="start" x="249.88" y="-29.57" font-family="Times,serif" font-size="14.00">SR2</text>
# </g>
#
# <g id="node4" class="node">
# <title>3</title>
# <ellipse fill="white" stroke="black" cx="554" cy="-34" rx="40.58" ry="18"></ellipse>
# <text text-anchor="start" x="531.5" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(3) </text>
# <text text-anchor="start" x="549.5" y="-29.57" font-family="Times,serif" font-size="14.00">SR3+</text>
# </g>
#
# <g id="node5" class="node">
# <title>4</title>
# <ellipse fill="white" stroke="black" cx="441" cy="-34" rx="54.06" ry="18"></ellipse>
# <text text-anchor="start" x="408.38" y="-29.57" font-family="Times,serif" font-size="9.00" fill="#999999">(4) </text>
# <text text-anchor="start" x="426.38" y="-29.57" font-family="Times,serif" font-size="14.00">Transit</text>
# </g>
#
# <g id="edge4" class="edge">
# <title>7-&gt;1</title>
# <path fill="none" stroke="black" d="M337,-87.7C337,-80.24 337,-71.32 337,-62.97"></path>
# <polygon fill="black" stroke="black" points="340.5,-63.1 337,-53.1 333.5,-63.1 340.5,-63.1"></polygon>
# </g>
#
# <g id="edge5" class="edge">
# <title>7-&gt;2</title>
# <path fill="none" stroke="black" d="M315.74,-87.7C304.29,-78.38 290.06,-66.79 277.85,-56.86"></path>
# <polygon fill="black" stroke="black" points="280.36,-53.57 270.39,-49.97 275.94,-59 280.36,-53.57"></polygon>
# </g>
#
# <g id="edge6" class="edge">
# <title>7-&gt;3</title>
# <path fill="none" stroke="black" d="M384.59,-94.86C418.45,-87 464.71,-74.94 504,-60 509.14,-58.04 514.46,-55.73 519.62,-53.31"></path>
# <polygon fill="black" stroke="black" points="520.81,-56.13 528.26,-48.6 517.74,-49.84 520.81,-56.13"></polygon>
# </g>
#
# <g id="edge7" class="edge">
# <title>7-&gt;4</title>
# <path fill="none" stroke="black" d="M362.98,-87.52C376.93,-78.13 394.24,-66.47 409.02,-56.53"></path>
# <polygon fill="black" stroke="black" points="410.49,-59.08 416.83,-50.59 406.58,-53.27 410.49,-59.08"></polygon>
# </g>
# </g>
# </svg></div>

# %% [markdown]
# This is a SVG format image, which renders great inside Jupyter and other HTML documents,
# but may not play nicely with Microsoft Word or Excel, if you are trying to put in in a report.
# To solve that, we can also produce a PNG format image file of the same thing.

# %%
m[18].graph.to_png()
# Out:
# <xmle.Elem 'img' with 0 children>

# %% [markdown]
# The PNG image can be saved to the file system with the argument `filename`, so you can easily get it out of the Jupyter notebook and into a Word, Excel, or other convenient document format.

# %%
m[18].graph.to_png(filename="./tmp/m18.png");

# %% [markdown]
# The `to_png` method also accepts a `figsize` argument, if we want to give the maximum width
# and height of the output, in inches.

# %%
m[18].graph.to_png(figsize=(1,1))
# Out:
# <xmle.Elem 'img' with 0 children>

# %% [markdown]
# You can make the output quite small, but the content doesn't dynamically scale with the figure size,
# so if it's too small it will be totally illegible.

# %%
m[18].graph.to_png(figsize=(0.25,0.25))
# Out:
# <xmle.Elem 'img' with 0 children>

# %% [markdown]
# Let's estimate all the simple models listed above and compare the.

# %%
m[19] = m[17].copy()
m[19].set_values('null')
m[19].title = "Model 19"
m[19].graph.new_node(name="Automobile", parameter="Automobile", children=[1,2,3]);
m[19].estimate(quiet=True);
# Out:
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# /opt/conda/envs/arboretum/lib/python3.10/site-packages/larch/model/optimization.py:308: UserWarning: slsqp may not play nicely with unbounded parameters
# if you get poor results, consider setting global bounds with model.set_cap()
#   warnings.warn( # infinite bounds # )

# %%
m[20] = m[17].copy()
m[20].set_values('null')
m[20].title = "Model 20"
m[20].graph.new_node(name="SharedRide", parameter="SharedRide", children=[2,3]);
m[20].estimate(quiet=True);
# Out:
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# /opt/conda/envs/arboretum/lib/python3.10/site-packages/larch/model/optimization.py:308: UserWarning: slsqp may not play nicely with unbounded parameters
# if you get poor results, consider setting global bounds with model.set_cap()
#   warnings.warn( # infinite bounds # )

# %%
m[21] = m[17].copy()
m[21].set_values('null')
m[21].title = "Model 21"
m[21].graph.new_node(name="NonMotorized", parameter="NonMotorized", children=[5,6]);
m[21].estimate(quiet=True);
# Out:
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# /opt/conda/envs/arboretum/lib/python3.10/site-packages/larch/model/optimization.py:308: UserWarning: slsqp may not play nicely with unbounded parameters
# if you get poor results, consider setting global bounds with model.set_cap()
#   warnings.warn( # infinite bounds # )

# %%
# A helper function to create a small grid of images to show nests
from xmle import Elem
def table_of_images(content, ncols=2):
    col = 0
    t = Elem("table")            # Top level HTML table element
    tr = t.elem("tr")            # start a first <tr> table row
    cell_css = 'text-align:center;font-weight:bold;background-color:white' # formatting
    for k,v in content.items():  # Loop over title/image content of table
        cell = tr.elem("td", style=cell_css, text=k) # start a <td> table data cell
        cell.append(v)           # add the content
        col += 1                 # move to next column
        if col == ncols:         # or if we were in the last column
            tr = t.elem("tr")    # start a new <tr> table row
            col = 0              # and move back to the first column
    return t

# %% [markdown]
# #### Nesting Tree Figures

# %%
table_of_images({
    f'Model {n}':m[n].graph.to_png(figsize=(4,3), filename=f'./tmp/model_{n}.png') 
    for n in (18,19,20,21)
})
# Out:
# <xmle.Elem 'table' with 3 children>

# %% [markdown]
# #### Table of Results

# %%
from larch.util.summary import joint_parameter_summary

joint_parameter_summary(
    [m[i] for i in (17,18,19,20,21)], 
    ordering=m[17].ordering,
    bases=[m_c,]
)
# Out:
#                                    Model 17           Model 18
#                                       Param  t-Stat      Param  t-Stat
# Category       Parameter
# LoS            totcost/hhinc        -0.0524   -5.04    -0.0524   -5.04  \
#                motor_time           -0.0202   -5.29    -0.0202   -5.29
#                nonmotor_time        -0.0454   -7.88    -0.0454   -7.88
#                ovtt/dist             -0.133   -6.76     -0.133   -6.76
# HH             hhinc#4             -0.00532   -2.69   -0.00532   -2.69
#                hhinc#5             -0.00864   -1.68   -0.00864   -1.68
#                hhinc#6             -0.00599   -1.90   -0.00600   -1.90
#                numveh#23             -0.317   -4.75     -0.317   -4.75
#                numveh#4              -0.947   -8.00     -0.947   -8.00
#                numveh#5              -0.703   -2.72     -0.703   -2.72
#                numveh#6              -0.723   -4.26     -0.722   -4.26
# Zone           wkempden#2           0.00158    4.04    0.00158    4.04
#                wkempden#3           0.00226    4.99    0.00226    4.99
#                wkempden#4           0.00313    8.68    0.00313    8.68
#                wkempden#5           0.00193    1.59    0.00193    1.59
#                wkempden#6           0.00289    3.90    0.00289    3.89
#                wkccbd#2               0.260    2.11      0.260    2.11
#                wkccbd#3                1.07    5.59       1.07    5.59
#                wkccbd#4                1.31    7.90       1.31    7.90
#                wkccbd#5               0.489    1.35      0.489    1.35
#                wkccbd#6               0.102    0.40      0.102    0.40
# ASCs           ASC_BIKE               -1.63   -3.81      -1.63   -3.81
#                ASC_SR2                -1.81  -17.03      -1.81  -17.03
#                ASC_SR3P               -3.43  -22.61      -3.43  -22.61
#                ASC_TRAN              -0.684   -2.76     -0.684   -2.76
#                ASC_WALK              0.0688    0.20     0.0690    0.20
# Other          Automobile
#                NonMotorized
#                SharedRide
# ----           ----                    ----    ----       ----    ----
# Log Likelihood Converged          -3,444.14          -3,444.14
#                Null               -7,309.60          -7,309.60
#                Constants Only     -4,132.92          -4,132.92
# Rho Squared    vs Null               0.5288             0.5288
#                vs Constants Only     0.1667             0.1667
#
#                                    Model 19           Model 20
#                                       Param  t-Stat      Param  t-Stat
# Category       Parameter
# LoS            totcost/hhinc        -0.0524   -5.04    -0.0455   -4.25  \
#                motor_time           -0.0202   -5.29    -0.0206   -5.65
#                nonmotor_time        -0.0454   -7.88    -0.0452   -7.85
#                ovtt/dist             -0.133   -6.76     -0.134   -6.81
# HH             hhinc#4             -0.00532   -2.69   -0.00541   -2.74
#                hhinc#5             -0.00864   -1.68   -0.00890   -1.72
#                hhinc#6             -0.00600   -1.90   -0.00623   -1.97
#                numveh#23             -0.317   -4.75     -0.315   -4.73
#                numveh#4              -0.947   -8.00     -0.938   -7.95
#                numveh#5              -0.702   -2.72     -0.703   -2.72
#                numveh#6              -0.722   -4.26     -0.725   -4.28
# Zone           wkempden#2           0.00158    4.04    0.00188    5.35
#                wkempden#3           0.00226    4.99    0.00192    5.36
#                wkempden#4           0.00313    8.68    0.00322    8.83
#                wkempden#5           0.00193    1.59    0.00202    1.66
#                wkempden#6           0.00289    3.89    0.00297    4.00
#                wkccbd#2               0.260    2.11      0.396    3.48
#                wkccbd#3                1.07    5.59      0.641    4.46
#                wkccbd#4                1.31    7.90       1.32    7.96
#                wkccbd#5               0.489    1.35      0.501    1.39
#                wkccbd#6               0.102    0.40      0.114    0.45
# ASCs           ASC_BIKE               -1.63   -3.81      -1.62   -3.79
#                ASC_SR2                -1.81  -17.03      -1.68  -15.80
#                ASC_SR3P               -3.43  -22.61      -2.21   -8.43
#                ASC_TRAN              -0.684   -2.76     -0.679   -2.77
#                ASC_WALK              0.0689    0.20     0.0740    0.21
# Other          Automobile              1.00      NA
#                NonMotorized
#                SharedRide                                0.329   -5.22
# ----           ----                    ----    ----       ----    ----
# Log Likelihood Converged          -3,444.14          -3,442.37
#                Null               -7,309.60          -7,309.60
#                Constants Only     -4,132.92          -4,132.92
# Rho Squared    vs Null               0.5288             0.5291
#                vs Constants Only     0.1667             0.1671
#
#                                    Model 21
#                                       Param  t-Stat
# Category       Parameter
# LoS            totcost/hhinc        -0.0519   -4.99
#                motor_time           -0.0199   -5.22
#                nonmotor_time        -0.0454   -8.25
#                ovtt/dist             -0.135   -6.82
# HH             hhinc#4             -0.00534   -2.70
#                hhinc#5             -0.00922   -2.00
#                hhinc#6             -0.00560   -1.85
#                numveh#23             -0.317   -4.75
#                numveh#4              -0.947   -8.01
#                numveh#5              -0.693   -3.08
#                numveh#6              -0.715   -4.40
# Zone           wkempden#2           0.00158    4.05
#                wkempden#3           0.00226    5.01
#                wkempden#4           0.00314    8.69
#                wkempden#5           0.00219    2.03
#                wkempden#6           0.00279    3.78
#                wkccbd#2               0.260    2.11
#                wkccbd#3                1.07    5.60
#                wkccbd#4                1.31    7.90
#                wkccbd#5               0.414    1.25
#                wkccbd#6               0.103    0.43
# ASCs           ASC_BIKE               -1.45   -3.64
#                ASC_SR2                -1.81  -17.05
#                ASC_SR3P               -3.43  -22.62
#                ASC_TRAN              -0.681   -2.75
#                ASC_WALK              0.0796    0.24
# Other          Automobile
#                NonMotorized           0.766   -1.28
#                SharedRide
# ----           ----                    ----    ----
# Log Likelihood Converged          -3,443.51
#                Null               -7,309.60
#                Constants Only     -4,132.92
# Rho Squared    vs Null               0.5289
#                vs Constants Only     0.1668

# %%
value_of_time(m[17])
# Out:
#                % Wage Rate     $10/hr     $20/hr      $40/hr
# Non-Motor          104.04%  $10.40/hr  $20.81/hr   $41.62/hr
# IVTT                46.22%   $4.62/hr   $9.24/hr   $18.49/hr
# OVTT @ 1 mile      350.34%  $35.03/hr  $70.07/hr  $140.14/hr
# OVTT @ 5 mile      107.05%  $10.70/hr  $21.41/hr   $42.82/hr
# OVTT @ 10 mile      76.64%   $7.66/hr  $15.33/hr   $30.65/hr

# %%
pd.DataFrame({
    m[i].title: value_of_time(m[i]).stack() 
    for i in (17,18,19,20,21)
})
# Out:
#                               Model 17    Model 18    Model 19    Model 20
# Non-Motor      % Wage Rate     104.04%     104.04%     104.04%     119.22%  \
#                $10/hr        $10.40/hr   $10.40/hr   $10.40/hr   $11.92/hr
#                $20/hr        $20.81/hr   $20.81/hr   $20.81/hr   $23.84/hr
#                $40/hr        $41.62/hr   $41.62/hr   $41.62/hr   $47.69/hr
# IVTT           % Wage Rate      46.22%      46.22%      46.22%      54.22%
#                $10/hr         $4.62/hr    $4.62/hr    $4.62/hr    $5.42/hr
#                $20/hr         $9.24/hr    $9.24/hr    $9.24/hr   $10.84/hr
#                $40/hr        $18.49/hr   $18.49/hr   $18.49/hr   $21.69/hr
# OVTT @ 1 mile  % Wage Rate     350.34%     350.37%     350.37%     406.90%
#                $10/hr        $35.03/hr   $35.04/hr   $35.04/hr   $40.69/hr
#                $20/hr        $70.07/hr   $70.07/hr   $70.07/hr   $81.38/hr
#                $40/hr       $140.14/hr  $140.15/hr  $140.15/hr  $162.76/hr
# OVTT @ 5 mile  % Wage Rate     107.05%     107.05%     107.05%     124.76%
#                $10/hr        $10.70/hr   $10.71/hr   $10.70/hr   $12.48/hr
#                $20/hr        $21.41/hr   $21.41/hr   $21.41/hr   $24.95/hr
#                $40/hr        $42.82/hr   $42.82/hr   $42.82/hr   $49.90/hr
# OVTT @ 10 mile % Wage Rate      76.64%      76.64%      76.63%      89.49%
#                $10/hr         $7.66/hr    $7.66/hr    $7.66/hr    $8.95/hr
#                $20/hr        $15.33/hr   $15.33/hr   $15.33/hr   $17.90/hr
#                $40/hr        $30.65/hr   $30.65/hr   $30.65/hr   $35.79/hr
#
#                               Model 21
# Non-Motor      % Wage Rate     104.89%
#                $10/hr        $10.49/hr
#                $20/hr        $20.98/hr
#                $40/hr        $41.96/hr
# IVTT           % Wage Rate      46.02%
#                $10/hr         $4.60/hr
#                $20/hr         $9.20/hr
#                $40/hr        $18.41/hr
# OVTT @ 1 mile  % Wage Rate     358.28%
#                $10/hr        $35.83/hr
#                $20/hr        $71.66/hr
#                $40/hr       $143.31/hr
# OVTT @ 5 mile  % Wage Rate     108.47%
#                $10/hr        $10.85/hr
#                $20/hr        $21.69/hr
#                $40/hr        $43.39/hr
# OVTT @ 10 mile % Wage Rate      77.24%
#                $10/hr         $7.72/hr
#                $20/hr        $15.45/hr
#                $40/hr        $30.90/hr

# %% [markdown]
# #### Hypothesis Testing

# %%
from scipy.stats import chi2

def LRT(model_u, model_r, deg_free):
    stat = 2*(model_u.loglike() - model_r.loglike())
    p = chi2(df=deg_free).sf(stat)
    return f"{stat:.3f}, p={p:.3f}, df={deg_free}"

# %%
for i in (18,19,20,21):
    print(m[i].title,"vs",m[17].title,": Chi-Sq=",LRT(m[i], m[17], 1))
# Out:
# Model 18 vs Model 17 : Chi-Sq= 0.000, p=0.998, df=1
# Model 19 vs Model 17 : Chi-Sq= 0.000, p=0.998, df=1
# Model 20 vs Model 17 : Chi-Sq= 3.541, p=0.060, df=1
# Model 21 vs Model 17 : Chi-Sq= 1.261, p=0.261, df=1

# %% [markdown]
# ### Two Nests for Different Groups

# %%
m[22] = m[17].copy()
m[22].set_values('null')
m[22].title = "Model 22"
m[22].graph.new_node(name="Motorized", parameter="Motorized", children=[1,2,3,4]);
m[22].graph.new_node(name="NonMotorized", parameter="NonMotorized", children=[5,6]);
m[22].estimate(quiet=True);
# Out:
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# /opt/conda/envs/arboretum/lib/python3.10/site-packages/larch/model/optimization.py:308: UserWarning: slsqp may not play nicely with unbounded parameters
# if you get poor results, consider setting global bounds with model.set_cap()
#   warnings.warn( # infinite bounds # )

# %%
m[23] = m[17].copy()
m[23].set_values('null')
m[23].title = "Model 23"
m[23].graph.new_node(name="Automobile", parameter="Automobile", children=[1,2,3]);
m[23].graph.new_node(name="NonMotorized", parameter="NonMotorized", children=[5,6]);
m[23].estimate(quiet=True);
# Out:
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# /opt/conda/envs/arboretum/lib/python3.10/site-packages/larch/model/optimization.py:308: UserWarning: slsqp may not play nicely with unbounded parameters
# if you get poor results, consider setting global bounds with model.set_cap()
#   warnings.warn( # infinite bounds # )

# %%
m[24] = m[17].copy()
m[24].set_values('null')
m[24].title = "Model 24"
m[24].graph.new_node(name="SharedRide", parameter="SharedRide", children=[2,3]);
m[24].graph.new_node(name="NonMotorized", parameter="NonMotorized", children=[5,6]);
m[24].estimate(quiet=True);
# Out:
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# /opt/conda/envs/arboretum/lib/python3.10/site-packages/larch/model/optimization.py:308: UserWarning: slsqp may not play nicely with unbounded parameters
# if you get poor results, consider setting global bounds with model.set_cap()
#   warnings.warn( # infinite bounds # )

# %% [markdown]
# #### Nesting Tree Figures

# %%
table_of_images({f'Model {n}':m[n].graph.to_png(figsize=(4,3)) for n in (22,23,24)})
# Out:
# <xmle.Elem 'table' with 2 children>

# %% [markdown]
# #### Table of Results

# %%
joint_parameter_summary([m[i] for i in (17,22,23,24)], ordering=m[17].ordering)
# Out:
#                                Model 17           Model 22          Model 23
#                                   Param  t-Stat      Param t-Stat      Param
# Category       Parameter
# LoS            totcost/hhinc    -0.0524   -5.04    -0.0386  -3.72    -0.0519  \
#                motor_time       -0.0202   -5.29    -0.0145  -3.76    -0.0199
#                nonmotor_time    -0.0454   -7.88    -0.0462  -8.56    -0.0454
#                ovtt/dist         -0.133   -6.76     -0.114  -5.39     -0.135
# HH             hhinc#4         -0.00532   -2.69   -0.00393  -2.44   -0.00534
#                hhinc#5         -0.00864   -1.68    -0.0100  -2.16   -0.00922
#                hhinc#6         -0.00599   -1.90   -0.00621  -2.05   -0.00560
#                numveh#23         -0.317   -4.75     -0.226  -3.47     -0.317
#                numveh#4          -0.947   -8.00     -0.707  -4.72     -0.947
#                numveh#5          -0.703   -2.72     -0.735  -3.21     -0.693
#                numveh#6          -0.723   -4.26     -0.765  -4.68     -0.715
# Zone           wkempden#2       0.00158    4.04    0.00115   3.24    0.00158
#                wkempden#3       0.00226    4.99    0.00164   3.65    0.00226
#                wkempden#4       0.00313    8.68    0.00224   4.41    0.00314
#                wkempden#5       0.00193    1.59    0.00167   1.54    0.00219
#                wkempden#6       0.00289    3.90    0.00217   2.85    0.00279
#                wkccbd#2           0.260    2.11      0.193   2.01      0.260
#                wkccbd#3            1.07    5.59      0.781   3.91       1.07
#                wkccbd#4            1.31    7.90      0.921   4.15       1.31
#                wkccbd#5           0.489    1.35      0.408   1.24      0.414
#                wkccbd#6           0.102    0.40      0.114   0.48      0.103
# ASCs           ASC_BIKE           -1.63   -3.81      -1.20  -2.88      -1.45
#                ASC_SR2            -1.81  -17.03      -1.32  -5.20      -1.81
#                ASC_SR3P           -3.43  -22.61      -2.50  -5.27      -3.43
#                ASC_TRAN          -0.684   -2.76     -0.403  -1.82     -0.681
#                ASC_WALK          0.0688    0.20      0.346   0.97     0.0796
# Other          Automobile                                               1.00
#                Motorized                             0.726  -2.03
#                NonMotorized                          0.769  -1.29      0.766
#                SharedRide
# ----           ----                ----    ----       ----   ----       ----
# Log Likelihood Converged      -3,444.14          -3,441.63         -3,443.51
#                Null           -7,309.60          -7,309.60         -7,309.60
# Rho Squared    vs Null           0.5288             0.5292            0.5289
#
#                                        Model 24
#                               t-Stat      Param  t-Stat
# Category       Parameter
# LoS            totcost/hhinc   -4.99    -0.0450   -4.20
#                motor_time      -5.22    -0.0203   -5.58
#                nonmotor_time   -8.25    -0.0452   -8.23
#                ovtt/dist       -6.82     -0.136   -6.87
# HH             hhinc#4         -2.70   -0.00543   -2.75
#                hhinc#5         -2.00   -0.00949   -2.06
#                hhinc#6         -1.85   -0.00583   -1.92
#                numveh#23       -4.75     -0.315   -4.73
#                numveh#4        -8.01     -0.939   -7.96
#                numveh#5        -3.08     -0.694   -3.09
#                numveh#6        -4.40     -0.717   -4.41
# Zone           wkempden#2       4.05    0.00188    5.36
#                wkempden#3       5.01    0.00192    5.38
#                wkempden#4       8.69    0.00322    8.84
#                wkempden#5       2.03    0.00229    2.12
#                wkempden#6       3.78    0.00286    3.88
#                wkccbd#2         2.11      0.397    3.50
#                wkccbd#3         5.60      0.639    4.47
#                wkccbd#4         7.90       1.32    7.96
#                wkccbd#5         1.25      0.425    1.29
#                wkccbd#6         0.43      0.116    0.48
# ASCs           ASC_BIKE        -3.64      -1.43   -3.62
#                ASC_SR2        -17.05      -1.68  -15.81
#                ASC_SR3P       -22.62      -2.20   -8.48
#                ASC_TRAN        -2.75     -0.676   -2.75
#                ASC_WALK         0.24     0.0848    0.25
# Other          Automobile         NA
#                Motorized
#                NonMotorized    -1.28      0.762   -1.31
#                SharedRide                 0.324   -5.31
# ----           ----             ----       ----    ----
# Log Likelihood Converged              -3,441.72
#                Null                   -7,309.60
# Rho Squared    vs Null                   0.5292

# %%
pd.DataFrame({
    m[i].title: value_of_time(m[i]).stack() 
    for i in (17,22,23,24)
})
# Out:
#                               Model 17    Model 22    Model 23    Model 24
# Non-Motor      % Wage Rate     104.04%     143.66%     104.89%     120.55%
#                $10/hr        $10.40/hr   $14.37/hr   $10.49/hr   $12.05/hr
#                $20/hr        $20.81/hr   $28.73/hr   $20.98/hr   $24.11/hr
#                $40/hr        $41.62/hr   $57.47/hr   $41.96/hr   $48.22/hr
# IVTT           % Wage Rate      46.22%      45.14%      46.02%      54.19%
#                $10/hr         $4.62/hr    $4.51/hr    $4.60/hr    $5.42/hr
#                $20/hr         $9.24/hr    $9.03/hr    $9.20/hr   $10.84/hr
#                $40/hr        $18.49/hr   $18.06/hr   $18.41/hr   $21.68/hr
# OVTT @ 1 mile  % Wage Rate     350.34%     398.79%     358.28%     417.44%
#                $10/hr        $35.03/hr   $39.88/hr   $35.83/hr   $41.74/hr
#                $20/hr        $70.07/hr   $79.76/hr   $71.66/hr   $83.49/hr
#                $40/hr       $140.14/hr  $159.51/hr  $143.31/hr  $166.97/hr
# OVTT @ 5 mile  % Wage Rate     107.05%     115.87%     108.47%     126.84%
#                $10/hr        $10.70/hr   $11.59/hr   $10.85/hr   $12.68/hr
#                $20/hr        $21.41/hr   $23.17/hr   $21.69/hr   $25.37/hr
#                $40/hr        $42.82/hr   $46.35/hr   $43.39/hr   $50.74/hr
# OVTT @ 10 mile % Wage Rate      76.64%      80.50%      77.24%      90.51%
#                $10/hr         $7.66/hr    $8.05/hr    $7.72/hr    $9.05/hr
#                $20/hr        $15.33/hr   $16.10/hr   $15.45/hr   $18.10/hr
#                $40/hr        $30.65/hr   $32.20/hr   $30.90/hr   $36.21/hr

# %% [markdown]
# #### Hypothesis Testing

# %%
for i in (22,23,24):
    print(m[i].title,"vs",m[17].title,": Chi-Sq=",LRT(m[i], m[17], 1))
# Out:
# Model 22 vs Model 17 : Chi-Sq= 5.029, p=0.025, df=1
# Model 23 vs Model 17 : Chi-Sq= 1.261, p=0.261, df=1
# Model 24 vs Model 17 : Chi-Sq= 4.848, p=0.028, df=1

# %% [markdown]
# ### Hierarchical Nests

# %%
m[25] = m[17].copy()
m[25].set_values('null')
m[25].title = "Model 25"
auto = m[25].graph.new_node(name="Automobile", parameter="Automobile", children=[1,2,3]);
m[25].graph.new_node(name="Motorized", parameter="Motorized", children=[auto, 4]);
m[25].estimate(quiet=True);
# Out:
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# /opt/conda/envs/arboretum/lib/python3.10/site-packages/larch/model/optimization.py:308: UserWarning: slsqp may not play nicely with unbounded parameters
# if you get poor results, consider setting global bounds with model.set_cap()
#   warnings.warn( # infinite bounds # )

# %%
m[26] = m[17].copy()
m[26].set_values('null')
m[26].title = "Model 26"
sr = m[26].graph.new_node(name="SharedRide", parameter="SharedRide", children=[2,3]);
m[26].graph.new_node(name="Motorized", parameter="Motorized", children=[1, sr, 4]);
m[26].estimate(quiet=True);
# Out:
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# /opt/conda/envs/arboretum/lib/python3.10/site-packages/larch/model/optimization.py:308: UserWarning: slsqp may not play nicely with unbounded parameters
# if you get poor results, consider setting global bounds with model.set_cap()
#   warnings.warn( # infinite bounds # )

# %%
m[27] = m[17].copy()
m[27].set_values('null')
m[27].title = "Model 27"
sr = m[27].graph.new_node(name="SharedRide", parameter="SharedRide", children=[2,3]);
m[27].graph.new_node(name="Automobile", parameter="Automobile", children=[1, sr]);
m[27].estimate(quiet=True);
# Out:
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# /opt/conda/envs/arboretum/lib/python3.10/site-packages/larch/model/optimization.py:308: UserWarning: slsqp may not play nicely with unbounded parameters
# if you get poor results, consider setting global bounds with model.set_cap()
#   warnings.warn( # infinite bounds # )

# %% [markdown]
# #### Nesting Tree Figures

# %%
table_of_images({f'Model {n}':m[n].graph.to_png(figsize=(4,3)) for n in (25,26,27)})
# Out:
# <xmle.Elem 'table' with 2 children>

# %% [markdown]
# #### Table of Results

# %%
joint_parameter_summary([m[i] for i in (17,25,26,27)], ordering=m[17].ordering)
# Out:
#                                Model 17           Model 25          Model 26
#                                   Param  t-Stat      Param t-Stat      Param
# Category       Parameter
# LoS            totcost/hhinc    -0.0524   -5.04    -0.0363  -3.81    -0.0336  \
#                motor_time       -0.0202   -5.29    -0.0106  -3.68    -0.0149
#                nonmotor_time    -0.0454   -7.88    -0.0471  -8.41    -0.0461
#                ovtt/dist         -0.133   -6.76    -0.0995  -5.43     -0.113
# HH             hhinc#4         -0.00532   -2.69   -0.00215  -1.84   -0.00400
#                hhinc#5         -0.00864   -1.68   -0.00905  -1.74   -0.00969
#                hhinc#6         -0.00599   -1.90   -0.00609  -1.95   -0.00677
#                numveh#23         -0.317   -4.75     -0.322  -3.78     -0.224
#                numveh#4          -0.947   -8.00     -0.463  -4.36     -0.700
#                numveh#5          -0.703   -2.72     -0.689  -2.66     -0.743
#                numveh#6          -0.723   -4.26     -0.706  -4.17     -0.774
# Zone           wkempden#2       0.00158    4.04    0.00158   3.54    0.00136
#                wkempden#3       0.00226    4.99    0.00235   4.06    0.00139
#                wkempden#4       0.00313    8.68    0.00194   4.61    0.00230
#                wkempden#5       0.00193    1.59    0.00142   1.18    0.00151
#                wkempden#6       0.00289    3.90    0.00219   2.91    0.00233
#                wkccbd#2           0.260    2.11      0.275   2.32      0.291
#                wkccbd#3            1.07    5.59       1.03   4.16      0.471
#                wkccbd#4            1.31    7.90      0.731   4.44      0.927
#                wkccbd#5           0.489    1.35      0.500   1.40      0.486
#                wkccbd#6           0.102    0.40      0.142   0.58      0.122
# ASCs           ASC_BIKE           -1.63   -3.81      -1.38  -3.11      -1.38
#                ASC_SR2            -1.81  -17.03      -1.63  -5.73      -1.23
#                ASC_SR3P           -3.43  -22.61      -3.15  -5.75      -1.62
#                ASC_TRAN          -0.684   -2.76     -0.407  -2.37     -0.401
#                ASC_WALK          0.0688    0.20      0.340   0.94      0.337
# Other          Automobile                            0.923  -0.48
#                Motorized                             0.532  -4.95      0.725
#                SharedRide                                              0.242
# ----           ----                ----    ----       ----   ----       ----
# Log Likelihood Converged      -3,444.14          -3,427.13         -3,440.56
#                Null           -7,309.60          -7,309.60         -7,309.60
# Rho Squared    vs Null           0.5288             0.5311            0.5293
#
#                                       Model 27
#                              t-Stat      Param  t-Stat
# Category       Parameter
# LoS            totcost/hhinc  -3.31    -0.0455   -4.25
#                motor_time     -3.84    -0.0206   -5.65
#                nonmotor_time  -8.15    -0.0452   -7.85
#                ovtt/dist      -5.39     -0.134   -6.81
# HH             hhinc#4        -2.47   -0.00542   -2.74
#                hhinc#5        -1.86   -0.00890   -1.72
#                hhinc#6        -2.15   -0.00623   -1.97
#                numveh#23      -3.43     -0.315   -4.73
#                numveh#4       -4.65     -0.939   -7.95
#                numveh#5       -2.82     -0.703   -2.72
#                numveh#6       -4.54     -0.725   -4.28
# Zone           wkempden#2      3.76    0.00188    5.35
#                wkempden#3      3.77    0.00192    5.36
#                wkempden#4      4.38    0.00322    8.83
#                wkempden#5      1.24    0.00202    1.66
#                wkempden#6      3.00    0.00297    4.00
#                wkccbd#2        2.95      0.396    3.48
#                wkccbd#3        3.45      0.641    4.46
#                wkccbd#4        4.11       1.32    7.96
#                wkccbd#5        1.36      0.501    1.39
#                wkccbd#6        0.50      0.114    0.45
# ASCs           ASC_BIKE       -3.07      -1.62   -3.79
#                ASC_SR2        -5.08      -1.68  -15.80
#                ASC_SR3P       -4.51      -2.21   -8.43
#                ASC_TRAN       -1.82     -0.679   -2.77
#                ASC_WALK        0.91     0.0740    0.21
# Other          Automobile                 1.00      NA
#                Motorized      -2.00
#                SharedRide     -7.16      0.329   -5.22
# ----           ----            ----       ----    ----
# Log Likelihood Converged             -3,442.37
#                Null                  -7,309.60
# Rho Squared    vs Null                  0.5291

# %%
pd.DataFrame({
    m[i].title: value_of_time(m[i]).stack() 
    for i in (17,25,26,27)
})
# Out:
#                               Model 17    Model 25    Model 26    Model 27
# Non-Motor      % Wage Rate     104.04%     155.64%     164.51%     119.22%
#                $10/hr        $10.40/hr   $15.56/hr   $16.45/hr   $11.92/hr
#                $20/hr        $20.81/hr   $31.13/hr   $32.90/hr   $23.84/hr
#                $40/hr        $41.62/hr   $62.26/hr   $65.80/hr   $47.69/hr
# IVTT           % Wage Rate      46.22%      34.92%      53.35%      54.22%
#                $10/hr         $4.62/hr    $3.49/hr    $5.33/hr    $5.42/hr
#                $20/hr         $9.24/hr    $6.98/hr   $10.67/hr   $10.84/hr
#                $40/hr        $18.49/hr   $13.97/hr   $21.34/hr   $21.69/hr
# OVTT @ 1 mile  % Wage Rate     350.34%     363.68%     456.85%     406.90%
#                $10/hr        $35.03/hr   $36.37/hr   $45.69/hr   $40.69/hr
#                $20/hr        $70.07/hr   $72.74/hr   $91.37/hr   $81.38/hr
#                $40/hr       $140.14/hr  $145.47/hr  $182.74/hr  $162.76/hr
# OVTT @ 5 mile  % Wage Rate     107.05%     100.67%     134.05%     124.76%
#                $10/hr        $10.70/hr   $10.07/hr   $13.40/hr   $12.48/hr
#                $20/hr        $21.41/hr   $20.13/hr   $26.81/hr   $24.95/hr
#                $40/hr        $42.82/hr   $40.27/hr   $53.62/hr   $49.90/hr
# OVTT @ 10 mile % Wage Rate      76.64%      67.79%      93.70%      89.49%
#                $10/hr         $7.66/hr    $6.78/hr    $9.37/hr    $8.95/hr
#                $20/hr        $15.33/hr   $13.56/hr   $18.74/hr   $17.90/hr
#                $40/hr        $30.65/hr   $27.12/hr   $37.48/hr   $35.79/hr

# %% [markdown]
# #### Hypothesis Testing

# %%
def LRT_2(i1,i2,df):
    print(m[i1].title,"vs",m[i2].title,": Chi-Sq=",LRT(m[i1], m[i2], df))

for i in (25,26,27):
    LRT_2(i,17,2)
    
LRT_2(25,19,1)
LRT_2(26,20,1)
# LRT_2(27,??,1)
# Out:
# Model 25 vs Model 17 : Chi-Sq= 34.032, p=0.000, df=2
# Model 26 vs Model 17 : Chi-Sq= 7.173, p=0.028, df=2
# Model 27 vs Model 17 : Chi-Sq= 3.541, p=0.170, df=2
# Model 25 vs Model 19 : Chi-Sq= 34.032, p=0.000, df=1
# Model 26 vs Model 20 : Chi-Sq= 3.631, p=0.057, df=1

# %% [markdown]
# ### More Complex Nests

# %%
m[28] = m[17].copy()
m[28].set_values('null')
m[28].title = "Model 28"
sr = m[28].graph.new_node(name="SharedRide", parameter="SharedRide", children=[2,3])
m[28].graph.new_node(name="Motorized", parameter="Motorized", children=[1, sr, 4])
m[28].graph.new_node(name="NonMotorized", parameter="NonMotorized", children=[5,6])
m[28].estimate(quiet=True);
# Out:
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# /opt/conda/envs/arboretum/lib/python3.10/site-packages/larch/model/optimization.py:308: UserWarning: slsqp may not play nicely with unbounded parameters
# if you get poor results, consider setting global bounds with model.set_cap()
#   warnings.warn( # infinite bounds # )

# %%
m[29] = m[17].copy()
m[29].set_values('null')
m[29].title = "Model 29"
sr = m[29].graph.new_node(name="SharedRide", parameter="SharedRide", children=[2,3])
auto = m[29].graph.new_node(name="Automobile", parameter="Automobile", children=[1,sr])
m[29].graph.new_node(name="Motorized", parameter="Motorized", children=[auto, 4])
m[29].estimate(quiet=True);
# Out:
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# /opt/conda/envs/arboretum/lib/python3.10/site-packages/larch/model/optimization.py:308: UserWarning: slsqp may not play nicely with unbounded parameters
# if you get poor results, consider setting global bounds with model.set_cap()
#   warnings.warn( # infinite bounds # )

# %% [markdown]
# #### Nesting Tree Figures

# %%
table_of_images({f'Model {n}':m[n].graph.to_png(figsize=(4,3)) for n in (28,29)})
# Out:
# <xmle.Elem 'table' with 2 children>

# %% [markdown]
# #### Table of Results

# %%
joint_parameter_summary([m[i] for i in (17,28,29)], ordering=m[17].ordering)
# Out:
#                                Model 17           Model 28          Model 29
#                                   Param  t-Stat      Param t-Stat      Param
# Category       Parameter
# LoS            totcost/hhinc    -0.0524   -5.04    -0.0334  -3.32    -0.0316  \
#                motor_time       -0.0202   -5.29    -0.0149  -3.88    -0.0111
#                nonmotor_time    -0.0454   -7.88    -0.0460  -8.53    -0.0470
#                ovtt/dist         -0.133   -6.76     -0.115  -5.41     -0.100
# HH             hhinc#4         -0.00532   -2.69   -0.00402  -2.48   -0.00222
#                hhinc#5         -0.00864   -1.68    -0.0102  -2.20   -0.00920
#                hhinc#6         -0.00599   -1.90   -0.00638  -2.11   -0.00625
#                numveh#23         -0.317   -4.75     -0.225  -3.45     -0.323
#                numveh#4          -0.947   -8.00     -0.703  -4.69     -0.457
#                numveh#5          -0.703   -2.72     -0.736  -3.22     -0.689
#                numveh#6          -0.723   -4.26     -0.766  -4.69     -0.707
# Zone           wkempden#2       0.00158    4.04    0.00137   3.79    0.00191
#                wkempden#3       0.00226    4.99    0.00140   3.80    0.00195
#                wkempden#4       0.00313    8.68    0.00231   4.42    0.00199
#                wkempden#5       0.00193    1.59    0.00175   1.61    0.00148
#                wkempden#6       0.00289    3.90    0.00224   2.91    0.00225
#                wkccbd#2           0.260    2.11      0.293   2.96      0.416
#                wkccbd#3            1.07    5.59      0.472   3.48      0.578
#                wkccbd#4            1.31    7.90      0.930   4.15      0.737
#                wkccbd#5           0.489    1.35      0.415   1.27      0.508
#                wkccbd#6           0.102    0.40      0.123   0.52      0.150
# ASCs           ASC_BIKE           -1.63   -3.81      -1.19  -2.87      -1.38
#                ASC_SR2            -1.81  -17.03      -1.24  -5.14      -1.51
#                ASC_SR3P           -3.43  -22.61      -1.62  -4.57      -1.86
#                ASC_TRAN          -0.684   -2.76     -0.400  -1.81     -0.396
#                ASC_WALK          0.0688    0.20      0.348   0.97      0.341
# Other          Automobile                                              0.928
#                Motorized                             0.728  -2.00      0.533
#                NonMotorized                          0.766  -1.31
#                SharedRide                            0.241  -7.24      0.217
# ----           ----                ----    ----       ----   ----       ----
# Log Likelihood Converged      -3,444.14          -3,439.90         -3,425.12
#                Null           -7,309.60          -7,309.60         -7,309.60
# Rho Squared    vs Null           0.5288             0.5294            0.5314
#
#
#                              t-Stat
# Category       Parameter
# LoS            totcost/hhinc  -3.36
#                motor_time     -3.86
#                nonmotor_time  -8.39
#                ovtt/dist      -5.44
# HH             hhinc#4        -1.89
#                hhinc#5        -1.77
#                hhinc#6        -2.00
#                numveh#23      -3.77
#                numveh#4       -4.33
#                numveh#5       -2.66
#                numveh#6       -4.18
# Zone           wkempden#2      4.20
#                wkempden#3      4.24
#                wkempden#4      4.63
#                wkempden#5      1.23
#                wkempden#6      2.97
#                wkccbd#2        3.44
#                wkccbd#3        3.84
#                wkccbd#4        4.44
#                wkccbd#5        1.42
#                wkccbd#6        0.62
# ASCs           ASC_BIKE       -3.11
#                ASC_SR2        -5.69
#                ASC_SR3P       -5.12
#                ASC_TRAN       -2.33
#                ASC_WALK        0.94
# Other          Automobile     -0.45
#                Motorized      -4.93
#                NonMotorized
#                SharedRide     -7.90
# ----           ----            ----
# Log Likelihood Converged
#                Null
# Rho Squared    vs Null

# %%
pd.DataFrame({
    m[i].title: value_of_time(m[i]).stack() 
    for i in (17,28,29)
})
# Out:
#                               Model 17    Model 28    Model 29
# Non-Motor      % Wage Rate     104.04%     165.29%     178.08%
#                $10/hr        $10.40/hr   $16.53/hr   $17.81/hr
#                $20/hr        $20.81/hr   $33.06/hr   $35.62/hr
#                $40/hr        $41.62/hr   $66.12/hr   $71.23/hr
# IVTT           % Wage Rate      46.22%      53.32%      41.94%
#                $10/hr         $4.62/hr    $5.33/hr    $4.19/hr
#                $20/hr         $9.24/hr   $10.66/hr    $8.39/hr
#                $40/hr        $18.49/hr   $21.33/hr   $16.77/hr
# OVTT @ 1 mile  % Wage Rate     350.34%     465.45%     422.43%
#                $10/hr        $35.03/hr   $46.55/hr   $42.24/hr
#                $20/hr        $70.07/hr   $93.09/hr   $84.49/hr
#                $40/hr       $140.14/hr  $186.18/hr  $168.97/hr
# OVTT @ 5 mile  % Wage Rate     107.05%     135.75%     118.03%
#                $10/hr        $10.70/hr   $13.58/hr   $11.80/hr
#                $20/hr        $21.41/hr   $27.15/hr   $23.61/hr
#                $40/hr        $42.82/hr   $54.30/hr   $47.21/hr
# OVTT @ 10 mile % Wage Rate      76.64%      94.54%      79.98%
#                $10/hr         $7.66/hr    $9.45/hr    $8.00/hr
#                $20/hr        $15.33/hr   $18.91/hr   $16.00/hr
#                $40/hr        $30.65/hr   $37.82/hr   $31.99/hr

# %% [markdown]
# ### Fixing Some Issues

# %%
m[30] = m[17].copy()
m[30].set_values('null')
m[30].title = "Model 30"
sr = m[30].graph.new_node(name="SharedRide", parameter="SharedRide", children=[2,3])
auto = m[30].graph.new_node(name="Automobile", parameter="Automobile", children=[1,sr])
m[30].graph.new_node(name="Motorized", parameter="Motorized", children=[auto, 4])
m[30].lock_value('Automobile', 0.6)
m[30].lock_value('Motorized', 0.8)
m[30].estimate();
# Out:
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# <h3>Larch Model Dashboard</h3>
# <p>LL = ...</p>

# %%
m[31] = m[17].copy()
m[31].set_values('null')
m[31].title = "Model 31"
sr = m[31].graph.new_node(name="SharedRide", parameter="SharedRide", children=[2,3])
auto = m[31].graph.new_node(name="Automobile", parameter="Automobile", children=[1,sr])
m[31].graph.new_node(name="NonMotorized", parameter="NonMotorized", children=[5,6])
m[31].graph.new_node(name="Motorized", parameter="Motorized", children=[auto, 4])
m[31].estimate(quiet=True);
m[31].lock_value('Automobile', 0.6)
m[31].lock_value('Motorized', 0.8)
m[31].estimate(quiet=True);
# Out:
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# /opt/conda/envs/arboretum/lib/python3.10/site-packages/larch/model/optimization.py:308: UserWarning: slsqp may not play nicely with unbounded parameters
# if you get poor results, consider setting global bounds with model.set_cap()
#   warnings.warn( # infinite bounds # )
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# /opt/conda/envs/arboretum/lib/python3.10/site-packages/larch/model/optimization.py:308: UserWarning: slsqp may not play nicely with unbounded parameters
# if you get poor results, consider setting global bounds with model.set_cap()
#   warnings.warn( # infinite bounds # )

# %% [markdown]
# #### Table of Results

# %%
joint_parameter_summary([m[i] for i in (29,30,31)], ordering=m[17].ordering)
# Out:
#                                Model 29          Model 30           Model 31
#                                   Param t-Stat      Param  t-Stat      Param
# Category       Parameter
# LoS            totcost/hhinc    -0.0316  -3.36    -0.0308   -4.27    -0.0305  \
#                motor_time       -0.0111  -3.86    -0.0164   -5.68    -0.0163
#                nonmotor_time    -0.0470  -8.39    -0.0456   -8.15    -0.0456
#                ovtt/dist         -0.100  -5.44     -0.118   -6.95     -0.120
# HH             hhinc#4         -0.00222  -1.89   -0.00484   -3.04   -0.00486
#                hhinc#5         -0.00920  -1.77    -0.0102   -1.95    -0.0107
#                hhinc#6         -0.00625  -2.00   -0.00722   -2.30   -0.00683
#                numveh#23         -0.323  -3.77     -0.188   -4.58     -0.188
#                numveh#4          -0.457  -4.33     -0.817   -8.56     -0.818
#                numveh#5          -0.689  -2.66     -0.788   -2.95     -0.785
#                numveh#6          -0.707  -4.18     -0.830   -4.89     -0.821
# Zone           wkempden#2       0.00191   4.20    0.00107    4.98    0.00107
#                wkempden#3       0.00195   4.24    0.00109    4.93    0.00110
#                wkempden#4       0.00199   4.63    0.00243    8.98    0.00243
#                wkempden#5       0.00148   1.23    0.00153    1.28    0.00177
#                wkempden#6       0.00225   2.97    0.00236    3.32    0.00226
#                wkccbd#2           0.416   3.44      0.231    3.27      0.231
#                wkccbd#3           0.578   3.84      0.405    4.37      0.404
#                wkccbd#4           0.737   4.44       1.02    7.80       1.02
#                wkccbd#5           0.508   1.42      0.485    1.36      0.414
#                wkccbd#6           0.150   0.62      0.121    0.50      0.122
# ASCs           ASC_BIKE           -1.38  -3.11      -1.33   -3.09      -1.14
#                ASC_SR2            -1.51  -5.69      -1.01  -15.11      -1.01
#                ASC_SR3P           -1.86  -5.12      -1.37   -7.91      -1.37
#                ASC_TRAN          -0.396  -2.33     -0.379   -1.92     -0.375
#                ASC_WALK           0.341   0.94      0.389    1.17      0.402
# Other          Automobile         0.928  -0.45      0.600      NA      0.600
#                Motorized          0.533  -4.93      0.800      NA      0.800
#                NonMotorized                                            0.767
#                SharedRide         0.217  -7.90      0.234   -8.79      0.232
# ----           ----                ----   ----       ----    ----       ----
# Log Likelihood Converged      -3,425.12         -3,453.78          -3,453.13
#                Null           -7,309.60         -7,309.60          -7,309.60
# Rho Squared    vs Null           0.5314            0.5275             0.5276
#
#
#                               t-Stat
# Category       Parameter
# LoS            totcost/hhinc   -4.24
#                motor_time      -5.63
#                nonmotor_time   -8.55
#                ovtt/dist       -7.00
# HH             hhinc#4         -3.05
#                hhinc#5         -2.30
#                hhinc#6         -2.26
#                numveh#23       -4.57
#                numveh#4        -8.57
#                numveh#5        -3.41
#                numveh#6        -5.06
# Zone           wkempden#2       4.99
#                wkempden#3       4.95
#                wkempden#4       8.98
#                wkempden#5       1.68
#                wkempden#6       3.20
#                wkccbd#2         3.29
#                wkccbd#3         4.38
#                wkccbd#4         7.80
#                wkccbd#5         1.27
#                wkccbd#6         0.52
# ASCs           ASC_BIKE        -2.86
#                ASC_SR2        -15.12
#                ASC_SR3P        -7.94
#                ASC_TRAN        -1.90
#                ASC_WALK         1.25
# Other          Automobile         NA
#                Motorized          NA
#                NonMotorized    -1.30
#                SharedRide      -8.88
# ----           ----             ----
# Log Likelihood Converged
#                Null
# Rho Squared    vs Null

# %%
pd.DataFrame({
    m[i].title: value_of_time(m[i]).stack() 
    for i in (17,29,30,31)
})
# Out:
#                               Model 17    Model 29    Model 30    Model 31
# Non-Motor      % Wage Rate     104.04%     178.08%     178.00%     179.53%
#                $10/hr        $10.40/hr   $17.81/hr   $17.80/hr   $17.95/hr
#                $20/hr        $20.81/hr   $35.62/hr   $35.60/hr   $35.91/hr
#                $40/hr        $41.62/hr   $71.23/hr   $71.20/hr   $71.81/hr
# IVTT           % Wage Rate      46.22%      41.94%      64.16%      64.04%
#                $10/hr         $4.62/hr    $4.19/hr    $6.42/hr    $6.40/hr
#                $20/hr         $9.24/hr    $8.39/hr   $12.83/hr   $12.81/hr
#                $40/hr        $18.49/hr   $16.77/hr   $25.67/hr   $25.62/hr
# OVTT @ 1 mile  % Wage Rate     350.34%     422.43%     523.98%     534.17%
#                $10/hr        $35.03/hr   $42.24/hr   $52.40/hr   $53.42/hr
#                $20/hr        $70.07/hr   $84.49/hr  $104.80/hr  $106.83/hr
#                $40/hr       $140.14/hr  $168.97/hr  $209.59/hr  $213.67/hr
# OVTT @ 5 mile  % Wage Rate     107.05%     118.03%     156.13%     158.07%
#                $10/hr        $10.70/hr   $11.80/hr   $15.61/hr   $15.81/hr
#                $20/hr        $21.41/hr   $23.61/hr   $31.23/hr   $31.61/hr
#                $40/hr        $42.82/hr   $47.21/hr   $62.45/hr   $63.23/hr
# OVTT @ 10 mile % Wage Rate      76.64%      79.98%     110.15%     111.06%
#                $10/hr         $7.66/hr    $8.00/hr   $11.01/hr   $11.11/hr
#                $20/hr        $15.33/hr   $16.00/hr   $22.03/hr   $22.21/hr
#                $40/hr        $30.65/hr   $31.99/hr   $44.06/hr   $44.42/hr
